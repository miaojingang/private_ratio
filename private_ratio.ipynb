# %% [markdown]
# <a href="https://colab.research.google.com/github/miaojingang/private_ratio/blob/main/private_ratio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook has the simulation used in paper
#
# > Jingang Miao, Yiming Paul Li. (2021). Privacy Preserving Inference on the Ratio of Two Gaussians Using (Weighted) Sums. [arXiv:2110.15449](https://arxiv.org/abs/2110.15449).

# %%
#@title functions {form-width:"20%"}
import logging
import numpy as np
import pandas as pd
import functools
import warnings
warnings.filterwarnings('ignore')


def from_moments(m_s, m_y, v_s, v_y, v_ys, log_scale=False):
    """Gets mean and variance from moments of the means."""
    if log_scale:
        return np.log(m_s / m_y), (
            1. / m_s ** 2 * v_s
            -2 * v_ys / m_y / m_s
            + v_y / m_y ** 2
        )
    else:
        return m_s / m_y, (
            1. / m_y ** 2 * v_s
            - 2 * m_s / m_y **3 * v_ys
            + m_s ** 2 / m_y** 4 * v_y
        )

def moments_from_sums(s, s2, y, y2, ys, w, w2):
    """Gets moments of the means from sums."""
    effective_n = w ** 2 / w2
    return (
        s / w, y / w,  # m_s, m_y
        (s2 / w - (s / w) ** 2) / effective_n,  # v_s
        (y2 / w - (y / w) ** 2) / effective_n,  # v_y
        (ys / w - y * s / w ** 2) / effective_n  # v_ys
    )

def from_sums(s, s2, y, y2, ys, w, w2, log_scale=False):
    """Gets mean and variance from sums."""
    moments = moments_from_sums(s, s2, y, y2, ys, w, w2)
    return from_moments(*moments, log_scale=log_scale)

def get_ci_maybe_bound_by_0(m, v, bound_by_0=False):
    half = 1.96 * np.sqrt(v)
    if bound_by_0:
        return np.maximum(m - half, 0), m + half
    return m - half, m + half

def ci_length(ci):
    return ci[1] - ci[0]

def is_covered(ci, truth):
    return ci[0] < truth < ci[1]

def interval_score(ci, truth, alpha=0.05):
    # section 6.2 of https://sites.stat.washington.edu/raftery/Research/PDF/Gneiting2007jasa.pdf
    l, u = ci
    x = truth
    return (
        u - l  # length of ci
        + 2.0 / alpha * ((l - x) * (x < l) + (x - u) * (x > u))  # penalty for missing truth
    )

def get_noise_scale(Delta, epsilon, delta, mechanism):
    if mechanism == "gaussian":
        return Delta * np.sqrt(2 * np.log(1.25 / delta)) / epsilon
    elif mechanism == "laplace":
        return Delta / epsilon

def one_run_dp_sums(
    seed=0, n=1_000, u_w=1, B=200,
    epsilon=2, delta=1e-6, true=1.1, log_scale=False, mechanism="gaussian"):
    # seed=0; n=1_000; u_w=1; B=200; epsilon=2; delta=1e-6; true=1.1; log_scale=False
    np.random.seed(seed)
    s = np.random.beta(2, 2, size=n)
    y = np.random.binomial(n=1, p=s/true, size=n)
    l_w = 1 / u_w
    w = np.random.exponential(1., size=n).clip(l_w, u_w)

    if log_scale:
        true = np.log(true)
        maybe_log = np.log
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=False)
    else:
        maybe_log = lambda x: x
        # ratio is non-negative
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=True)

    if mechanism == "gaussian":
        gen_noise = np.random.normal
    elif mechanism == "laplace":
        gen_noise = np.random.laplace
    else:
        raise ValueError("Only gaussian and laplace mechanisms are supported")
 
    # public version
    sum_s = s @ w
    sum_s2 = (s ** 2) @ w
    sum_y = sum_y2 = y @ w
    sum_ys = (y * s) @ w
    sum_w = w.sum()
    sum_w2 = (w ** 2).sum()
    m_p, v_p = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    ci_p = get_ci(m_p, v_p)
    length_p = ci_length(ci_p)
    covered_p = is_covered(ci_p, true)
    interval_score_p = interval_score(ci_p, true)

    # DP: add normal noise
    if u_w == 1.0:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 5,
            delta = delta / 5, mechanism=mechanism)
    else:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 6,
            delta = delta / 6, mechanism=mechanism)
    
    sum_s += gen_noise(0, get_scale(u_w))
    sum_s2 += gen_noise(0, get_scale(u_w))
    sum_y += gen_noise(0, get_scale(u_w))
    sum_y2 = sum_y
    sum_ys += gen_noise(0, get_scale(u_w))
    sum_w += gen_noise(0, get_scale(u_w))
    if u_w == 1.0:
        sum_w2 = sum_w
    else:
        sum_w2 += gen_noise(0, get_scale(u_w ** 2))
    # no correction
    m, v_nc = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    bias = m - true
    effective_n = w.sum() ** 2 / (w ** 2).sum()
    ci_nc = get_ci(m, v_nc)
    length_nc = ci_length(ci_nc)
    covered_nc = is_covered(ci_nc, true)
    interval_score_nc = interval_score(ci_nc, true)

    # monte carlo correction
    v_extra = ((maybe_log(
        (sum_s + gen_noise(0, get_scale(u_w), size=B)) /
        (sum_y + gen_noise(0, get_scale(u_w), size=B))
        ) - m
    ) ** 2).mean()
    
    ci_m = get_ci(m, v_nc + v_extra)
    length_m = ci_length(ci_m)
    covered_m = is_covered(ci_m, true)
    interval_score_m = interval_score(ci_m, true)

    # analytical correction
    m_s, m_y, v_s, v_y, v_sy = moments_from_sums(sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2)
    _, v_a = from_moments(
        m_s * sum_w, m_y * sum_w,
        v_s * sum_w ** 2 + get_scale(u_w) ** 2,
        v_y * sum_w ** 2 + get_scale(u_w) ** 2,
        v_sy * sum_w ** 2, log_scale=log_scale
    )
    ci_a = get_ci(m, v_a)
    length_a = ci_length(ci_a)
    covered_a = is_covered(ci_a, true)
    interval_score_a = interval_score(ci_a, true)

    return (
        n, epsilon, delta,
        u_w, effective_n,
        length_p, covered_p, interval_score_p,
        length_nc, covered_nc, interval_score_nc,
        length_m, covered_m, interval_score_m,
        length_a, covered_a, interval_score_a,
        bias
    )

def sim(
    show_styled_result=True,
    show_latex_result=True,
    **kwargs):
    res = (
        pd.DataFrame.from_records(
            (one_run_dp_sums(seed, n=n, u_w=u_w, epsilon=epsilon, **kwargs)
            for seed in range(1_000)
            for u_w in [1, 3]
            for n in [5_000,10_000]
            for epsilon in [0.2, 0.5, 1.]
            ),
            columns = [
                "n", "epsilon", "delta", "u_w", "effective_n",
                "length_p", "coverage_p", "interval_score_p",
                "length_nc", "coverage_nc", "interval_score_nc",
                "length_m", "coverage_m", "interval_score_m",
                "length_a", "coverage_a", "interval_score_a",
                "bias"]
            )
        .groupby(["n", "u_w", "epsilon", "delta", ], as_index=False).mean()
    )
    if show_styled_result:
        display(
            res.style.hide_index()
            .format({
                "n": "{:,}",
                "epsilon": "{:.1f}", "effective_n": "{:,.0f}",
                "length_p": "{:.3f}", "coverage_p": "{:.3f}", "interval_score_p": "{:.3f}",
                "length_nc": "{:.3f}", "coverage_nc": "{:.3f}", "interval_score_nc": "{:.3f}",
                "length_m": "{:.3f}", "coverage_m": "{:.3f}", "interval_score_m": "{:.3f}",
                "length_a": "{:.3f}", "coverage_a": "{:.3f}", "interval_score_a": "{:.3f}",
                "bias": "{:.3f}"
            })
            .bar(subset=["coverage_p", "coverage_nc", "coverage_m", "coverage_a"],
                 color="lightgreen", vmin=0)
            .set_table_attributes("class='dataframe'")
        )
    if show_latex_result:
        cols = [
            "u_w", "effective_n",
            "n", "epsilon",
            "length_p", "coverage_p", "interval_score_p",
            "length_nc", "coverage_nc", "interval_score_nc",
            "length_m", "coverage_m", "interval_score_m",
            "length_a", "coverage_a", "interval_score_a",
        ]
        print(res[cols].round(3).to_latex())

# %% [markdown]
# ## Gaussian mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="gaussian")
# Out:
# <style type="text/css">
# #T_c02f9_row0_col6, #T_c02f9_row1_col6, #T_c02f9_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_c02f9_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 30.5%, transparent 30.5%);
# }
# #T_c02f9_row0_col12, #T_c02f9_row0_col15, #T_c02f9_row5_col12, #T_c02f9_row6_col6, #T_c02f9_row7_col6, #T_c02f9_row8_col6, #T_c02f9_row8_col9, #T_c02f9_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_c02f9_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 65.8%, transparent 65.8%);
# }
# #T_c02f9_row1_col12, #T_c02f9_row4_col12, #T_c02f9_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_c02f9_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_c02f9_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 89.7%, transparent 89.7%);
# }
# #T_c02f9_row2_col12, #T_c02f9_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_c02f9_row2_col15, #T_c02f9_row4_col15, #T_c02f9_row8_col15, #T_c02f9_row9_col6, #T_c02f9_row10_col6, #T_c02f9_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_c02f9_row3_col6, #T_c02f9_row4_col6, #T_c02f9_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_c02f9_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 9.7%, transparent 9.7%);
# }
# #T_c02f9_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_c02f9_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 27.8%, transparent 27.8%);
# }
# #T_c02f9_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 50.2%, transparent 50.2%);
# }
# #T_c02f9_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 36.3%, transparent 36.3%);
# }
# #T_c02f9_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.2%, transparent 97.2%);
# }
# #T_c02f9_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.5%, transparent 97.5%);
# }
# #T_c02f9_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 76.1%, transparent 76.1%);
# }
# #T_c02f9_row7_col12, #T_c02f9_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_c02f9_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 11.7%, transparent 11.7%);
# }
# #T_c02f9_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_c02f9_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_c02f9_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 33.6%, transparent 33.6%);
# }
# #T_c02f9_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.4%, transparent 97.4%);
# }
# #T_c02f9_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.1%, transparent 97.1%);
# }
# #T_c02f9_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 61.3%, transparent 61.3%);
# }
# #T_c02f9_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.3%, transparent 97.3%);
# }
# #T_c02f9_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.0%, transparent 97.0%);
# }
# </style>
# <table id="T_c02f9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c02f9_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_c02f9_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c02f9_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_c02f9_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_c02f9_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_c02f9_row0_col5" class="data row0 col5" >0.061</td>
#       <td id="T_c02f9_row0_col6" class="data row0 col6" >0.947</td>
#       <td id="T_c02f9_row0_col7" class="data row0 col7" >0.074</td>
#       <td id="T_c02f9_row0_col8" class="data row0 col8" >0.061</td>
#       <td id="T_c02f9_row0_col9" class="data row0 col9" >0.267</td>
#       <td id="T_c02f9_row0_col10" class="data row0 col10" >1.893</td>
#       <td id="T_c02f9_row0_col11" class="data row0 col11" >0.370</td>
#       <td id="T_c02f9_row0_col12" class="data row0 col12" >0.951</td>
#       <td id="T_c02f9_row0_col13" class="data row0 col13" >0.443</td>
#       <td id="T_c02f9_row0_col14" class="data row0 col14" >0.367</td>
#       <td id="T_c02f9_row0_col15" class="data row0 col15" >0.952</td>
#       <td id="T_c02f9_row0_col16" class="data row0 col16" >0.435</td>
#       <td id="T_c02f9_row0_col17" class="data row0 col17" >0.004</td>
#     </tr>
#     <tr>
#       <td id="T_c02f9_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_c02f9_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_c02f9_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_c02f9_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_c02f9_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_c02f9_row1_col5" class="data row1 col5" >0.061</td>
#       <td id="T_c02f9_row1_col6" class="data row1 col6" >0.947</td>
#       <td id="T_c02f9_row1_col7" class="data row1 col7" >0.074</td>
#       <td id="T_c02f9_row1_col8" class="data row1 col8" >0.061</td>
#       <td id="T_c02f9_row1_col9" class="data row1 col9" >0.575</td>
#       <td id="T_c02f9_row1_col10" class="data row1 col10" >0.459</td>
#       <td id="T_c02f9_row1_col11" class="data row1 col11" >0.156</td>
#       <td id="T_c02f9_row1_col12" class="data row1 col12" >0.949</td>
#       <td id="T_c02f9_row1_col13" class="data row1 col13" >0.188</td>
#       <td id="T_c02f9_row1_col14" class="data row1 col14" >0.156</td>
#       <td id="T_c02f9_row1_col15" class="data row1 col15" >0.949</td>
#       <td id="T_c02f9_row1_col16" class="data row1 col16" >0.186</td>
#       <td id="T_c02f9_row1_col17" class="data row1 col17" >0.001</td>
#     </tr>
#     <tr>
#       <td id="T_c02f9_row2_col0" class="data row2 col0" >5,000</td>
#       <td id="T_c02f9_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_c02f9_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_c02f9_row2_col3" class="data row2 col3" >0.000001</td>
#       <td id="T_c02f9_row2_col4" class=
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.061 &       0.947 &             0.074 &      0.061 &        0.267 &              1.893 &     0.370 &       0.951 &             0.443 &     0.367 &       0.952 &             0.435 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.061 &       0.947 &             0.074 &      0.061 &        0.575 &              0.459 &     0.156 &       0.949 &             0.188 &     0.156 &       0.949 &             0.186 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.061 &       0.947 &             0.074 &      0.061 &        0.784 &              0.155 &     0.094 &       0.947 &             0.111 &     0.094 &       0.947 &             0.111 \\
# 3  &    3 &     3080.197 &   5000 &      0.2 &     0.078 &       0.948 &             0.093 &      0.090 &        0.085 &              9.158 &     4.119 &       0.947 &             4.340 &     1.482 &       0.941 &             1.744 \\
# 4  &    3 &     3080.197 &   5000 &      0.5 &     0.078 &       0.948 &             0.093 &      0.077 &        0.243 &              2.903 &     0.547 &       0.949 &             0.646 &     0.534 &       0.947 &             0.632 \\
# 5  &    3 &     3080.197 &   5000 &      1.0 &     0.078 &       0.948 &             0.093 &      0.078 &        0.439 &              1.044 &     0.273 &       0.951 &             0.331 &     0.272 &       0.950 &             0.326 \\
# 6  &    1 &    10000.000 &  10000 &      0.2 &     0.043 &       0.955 &             0.049 &      0.043 &        0.317 &              0.917 &     0.184 &       0.924 &             0.236 &     0.184 &       0.928 &             0.235 \\
# 7  &    1 &    10000.000 &  10000 &      0.5 &     0.043 &       0.955 &             0.049 &      0.043 &        0.665 &              0.196 &     0.083 &       0.934 &             0.104 &     0.084 &       0.935 &             0.104 \\
# 8  &    1 &    10000.000 &  10000 &      1.0 &     0.043 &       0.955 &             0.049 &      0.043 &        0.874 &              0.075 &     0.056 &       0.951 &             0.066 &     0.056 &       0.947 &             0.066 \\
# 9  &    3 &     6160.230 &  10000 &      0.2 &     0.055 &       0.950 &             0.067 &      0.055 &        0.102 &              4.788 &     0.697 &       0.942 &             0.849 &     0.667 &       0.932 &             0.832 \\
# 10 &    3 &     6160.230 &  10000 &      0.5 &     0.055 &       0.950 &             0.067 &      0.055 &        0.294 &              1.416 &     0.267 &       0.926 &             0.344 &     0.266 &       0.924 &             0.343 \\
# 11 &    3 &     6160.230 &  10000 &      1.0 &     0.055 &       0.950 &             0.067 &      0.055 &        0.536 &              0.472 &     0.141 &       0.925 &             0.183 &     0.141 &       0.923 &             0.183 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200, mechanism="gaussian")
# Out:
# <style type="text/css">
# #T_3c068_row0_col6, #T_3c068_row1_col6, #T_3c068_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_3c068_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 30.5%, transparent 30.5%);
# }
# #T_3c068_row0_col12, #T_3c068_row5_col12, #T_3c068_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_3c068_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_3c068_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 65.4%, transparent 65.4%);
# }
# #T_3c068_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_3c068_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_3c068_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 89.9%, transparent 89.9%);
# }
# #T_3c068_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_3c068_row2_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.3%, transparent 97.3%);
# }
# #T_3c068_row3_col6, #T_3c068_row4_col6, #T_3c068_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_3c068_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 9.9%, transparent 9.9%);
# }
# #T_3c068_row3_col12, #T_3c068_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.3%, transparent 96.3%);
# }
# #T_3c068_row3_col15, #T_3c068_row4_col12, #T_3c068_row6_col6, #T_3c068_row7_col6, #T_3c068_row8_col6, #T_3c068_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_3c068_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 27.7%, transparent 27.7%);
# }
# #T_3c068_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_3c068_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 49.9%, transparent 49.9%);
# }
# #T_3c068_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_3c068_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 36.5%, transparent 36.5%);
# }
# #T_3c068_row6_col12, #T_3c068_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.9%, transparent 96.9%);
# }
# #T_3c068_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.2%, transparent 95.2%);
# }
# #T_3c068_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 76.5%, transparent 76.5%);
# }
# #T_3c068_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# #T_3c068_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.5%, transparent 95.5%);
# }
# #T_3c068_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.4%, transparent 97.4%);
# }
# #T_3c068_row9_col6, #T_3c068_row10_col6, #T_3c068_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_3c068_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 11.4%, transparent 11.4%);
# }
# #T_3c068_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_3c068_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.1%, transparent 96.1%);
# }
# #T_3c068_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 33.7%, transparent 33.7%);
# }
# #T_3c068_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.9%, transparent 94.9%);
# }
# #T_3c068_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 61.1%, transparent 61.1%);
# }
# #T_3c068_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.7%, transparent 94.7%);
# }
# </style>
# <table id="T_3c068_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c068_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_3c068_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_3c068_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_3c068_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_3c068_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_3c068_row0_col5" class="data row0 col5" >0.055</td>
#       <td id="T_3c068_row0_col6" class="data row0 col6" >0.948</td>
#       <td id="T_3c068_row0_col7" class="data row0 col7" >0.067</td>
#       <td id="T_3c068_row0_col8" class="data row0 col8" >0.055</td>
#       <td id="T_3c068_row0_col9" class="data row0 col9" >0.267</td>
#       <td id="T_3c068_row0_col10" class="data row0 col10" >1.719</td>
#       <td id="T_3c068_row0_col11" class="data row0 col11" >0.332</td>
#       <td id="T_3c068_row0_col12" class="data row0 col12" >0.952</td>
#       <td id="T_3c068_row0_col13" class="data row0 col13" >0.398</td>
#       <td id="T_3c068_row0_col14" class="data row0 col14" >0.332</td>
#       <td id="T_3c068_row0_col15" class="data row0 col15" >0.957</td>
#       <td id="T_3c068_row0_col16" class="data row0 col16" >0.392</td>
#       <td id="T_3c068_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_3c068_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_3c068_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_3c068_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_3c068_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_3c068_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_3c068_row1_col5" class="data row1 col5" >0.055</td>
#       <td id="T_3c068_row1_col6" class="data row1 col6" >0.948</td>
#       <td id="T_3c068_row1_col7" class="data row1 col7" >0.067</td>
#       <td id="T_3c068_row1_col8" class="data row1 col8" >0.055</td>
#       <td id="T_3c068_row1_col9" class="data row1 col9" >0.572</td>
#       <td id="T_3c068_row1_col10" class="data row1 col10" >0.418</td>
#       <td id="T_3c068_row1_col11" class="data row1 col11" >0.142</td>
#       <td id="T_3c068_row1_col12" class="data row1 col12" >0.948</td>
#       <td id="T_3c068_row1_col13" class="data row1 col13" >0.171</td>
#       <td id="T_3c068_row1_col14" class="data row1 col14" >0.142</td>
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.055 &       0.948 &             0.067 &      0.055 &        0.267 &              1.719 &     0.332 &       0.952 &             0.398 &     0.332 &       0.957 &             0.392 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.055 &       0.948 &             0.067 &      0.055 &        0.572 &              0.418 &     0.142 &       0.948 &             0.171 &     0.142 &       0.952 &             0.168 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.055 &       0.948 &             0.067 &      0.055 &        0.787 &              0.141 &     0.085 &       0.946 &             0.101 &     0.086 &       0.949 &             0.100 \\
# 3  &    3 &     3080.197 &   5000 &      0.2 &     0.071 &       0.947 &             0.085 &      0.079 &        0.087 &              8.097 &     1.329 &       0.921 &             1.360 &     1.255 &       0.975 &             1.331 \\
# 4  &    3 &     3080.197 &   5000 &      0.5 &     0.071 &       0.947 &             0.085 &      0.070 &        0.242 &              2.633 &     0.484 &       0.956 &             0.569 &     0.481 &       0.963 &             0.561 \\
# 5  &    3 &     3080.197 &   5000 &      1.0 &     0.071 &       0.947 &             0.085 &      0.070 &        0.437 &              0.951 &     0.247 &       0.952 &             0.297 &     0.247 &       0.955 &             0.293 \\
# 6  &    1 &    10000.000 &  10000 &      0.2 &     0.039 &       0.954 &             0.045 &      0.039 &        0.319 &              0.833 &     0.167 &       0.926 &             0.215 &     0.167 &       0.928 &             0.213 \\
# 7  &    1 &    10000.000 &  10000 &      0.5 &     0.039 &       0.954 &             0.045 &      0.039 &        0.669 &              0.178 &     0.076 &       0.934 &             0.095 &     0.076 &       0.931 &             0.094 \\
# 8  &    1 &    10000.000 &  10000 &      1.0 &     0.039 &       0.954 &             0.045 &      0.039 &        0.875 &              0.068 &     0.051 &       0.952 &             0.060 &     0.051 &       0.950 &             0.060 \\
# 9  &    3 &     6160.230 &  10000 &      0.2 &     0.050 &       0.951 &             0.060 &      0.050 &        0.100 &              4.321 &     0.607 &       0.938 &             0.734 &     0.598 &       0.937 &             0.735 \\
# 10 &    3 &     6160.230 &  10000 &      0.5 &     0.050 &       0.951 &             0.060 &      0.050 &        0.295 &              1.288 &     0.241 &       0.926 &             0.311 &     0.241 &       0.925 &             0.310 \\
# 11 &    3 &     6160.230 &  10000 &      1.0 &     0.050 &       0.951 &             0.060 &      0.050 &        0.535 &              0.429 &     0.128 &       0.921 &             0.166 &     0.128 &       0.923 &             0.166 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Laplace mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_f0009_row0_col6, #T_f0009_row1_col6, #T_f0009_row2_col6, #T_f0009_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_f0009_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 78.0%, transparent 78.0%);
# }
# #T_f0009_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_f0009_row0_col15, #T_f0009_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.7%, transparent 93.7%);
# }
# #T_f0009_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.6%, transparent 95.6%);
# }
# #T_f0009_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_f0009_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.5%, transparent 97.5%);
# }
# #T_f0009_row2_col9, #T_f0009_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_f0009_row2_col12, #T_f0009_row2_col15, #T_f0009_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_f0009_row3_col6, #T_f0009_row4_col6, #T_f0009_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_f0009_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 42.3%, transparent 42.3%);
# }
# #T_f0009_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_f0009_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.5%, transparent 90.5%);
# }
# #T_f0009_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 75.7%, transparent 75.7%);
# }
# #T_f0009_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.7%, transparent 92.7%);
# }
# #T_f0009_row5_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_f0009_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.5%, transparent 96.5%);
# }
# #T_f0009_row6_col6, #T_f0009_row7_col6, #T_f0009_row8_col6, #T_f0009_row8_col9, #T_f0009_row8_col12, #T_f0009_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_f0009_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.0%, transparent 87.0%);
# }
# #T_f0009_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_f0009_row6_col15, #T_f0009_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.6%, transparent 93.6%);
# }
# #T_f0009_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_f0009_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_f0009_row9_col6, #T_f0009_row10_col6, #T_f0009_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_f0009_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 53.7%, transparent 53.7%);
# }
# #T_f0009_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_f0009_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.6%, transparent 88.6%);
# }
# #T_f0009_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 83.4%, transparent 83.4%);
# }
# #T_f0009_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# #T_f0009_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.2%, transparent 95.2%);
# }
# #T_f0009_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.3%, transparent 97.3%);
# }
# </style>
# <table id="T_f0009_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0009_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_f0009_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_f0009_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_f0009_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_f0009_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_f0009_row0_col5" class="data row0 col5" >0.061</td>
#       <td id="T_f0009_row0_col6" class="data row0 col6" >0.947</td>
#       <td id="T_f0009_row0_col7" class="data row0 col7" >0.074</td>
#       <td id="T_f0009_row0_col8" class="data row0 col8" >0.061</td>
#       <td id="T_f0009_row0_col9" class="data row0 col9" >0.745</td>
#       <td id="T_f0009_row0_col10" class="data row0 col10" >0.200</td>
#       <td id="T_f0009_row0_col11" class="data row0 col11" >0.109</td>
#       <td id="T_f0009_row0_col12" class="data row0 col12" >0.962</td>
#       <td id="T_f0009_row0_col13" class="data row0 col13" >0.129</td>
#       <td id="T_f0009_row0_col14" class="data row0 col14" >0.089</td>
#       <td id="T_f0009_row0_col15" class="data row0 col15" >0.899</td>
#       <td id="T_f0009_row0_col16" class="data row0 col16" >0.138</td>
#       <td id="T_f0009_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_f0009_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_f0009_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_f0009_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_f0009_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_f0009_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_f0009_row1_col5" class="data row1 col5" >0.061</td>
#       <td id="T_f0009_row1_col6" class="data row1 col6" >0.947</td>
#       <td id="T_f0009_row1_col7" class="data row1 col7" >0.074</td>
#       <td id="T_f0009_row1_col8" class="data row1 col8" >0.061</td>
#       <td id="T_f0009_row1_col9" class="data row1 col9" >0.913</td>
#       <td id="T_f0009_row1_col10" class="data row1 col10" >0.086</td>
#       <td id="T_f0009_row1_col11" class="data row1 col11" >0.071</td>
#       <td id="T_f0009_row1_col12" class="data row1 col12" >0.954</td>
#       <td id="T_f0009_row1_col13" class="data row1 col13" >0.082</td>
#       <td id="T_f0009_row1_col14" class="data row1 col14" >0.066</td>
#       <td id="T_f0009_row1_col15" class="data row1 col15" >0.935</td>
#       <td id="T_f0009_row1_col16" class="data row1 col16" >0.083</td>
#       <td id="T_f0009_row1_col17" class="data row1 col17" >0.000</td>
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.061 &       0.947 &             0.074 &      0.061 &        0.745 &              0.200 &     0.109 &       0.962 &             0.129 &     0.089 &       0.899 &             0.138 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.061 &       0.947 &             0.074 &      0.061 &        0.913 &              0.086 &     0.071 &       0.954 &             0.082 &     0.066 &       0.935 &             0.083 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.061 &       0.947 &             0.074 &      0.061 &        0.936 &              0.075 &     0.064 &       0.949 &             0.075 &     0.062 &       0.944 &             0.075 \\
# 3  &    3 &     3080.197 &   5000 &      0.2 &     0.078 &       0.948 &             0.093 &      0.077 &        0.404 &              1.393 &     0.344 &       0.958 &             0.410 &     0.245 &       0.868 &             0.482 \\
# 4  &    3 &     3080.197 &   5000 &      0.5 &     0.078 &       0.948 &             0.093 &      0.078 &        0.723 &              0.307 &     0.152 &       0.956 &             0.184 &     0.121 &       0.899 &             0.197 \\
# 5  &    3 &     3080.197 &   5000 &      1.0 &     0.078 &       0.948 &             0.093 &      0.078 &        0.885 &              0.135 &     0.101 &       0.952 &             0.121 &     0.090 &       0.925 &             0.124 \\
# 6  &    1 &    10000.000 &  10000 &      0.2 &     0.043 &       0.955 &             0.049 &      0.043 &        0.831 &              0.096 &     0.063 &       0.947 &             0.074 &     0.054 &       0.898 &             0.079 \\
# 7  &    1 &    10000.000 &  10000 &      0.5 &     0.043 &       0.955 &             0.049 &      0.043 &        0.936 &              0.054 &     0.047 &       0.955 &             0.054 &     0.045 &       0.946 &             0.054 \\
# 8  &    1 &    10000.000 &  10000 &      1.0 &     0.043 &       0.955 &             0.049 &      0.043 &        0.955 &              0.050 &     0.044 &       0.964 &             0.051 &     0.044 &       0.959 &             0.050 \\
# 9  &    3 &     6160.230 &  10000 &      0.2 &     0.055 &       0.950 &             0.067 &      0.055 &        0.513 &              0.597 &     0.173 &       0.946 &             0.216 &     0.128 &       0.850 &             0.256 \\
# 10 &    3 &     6160.230 &  10000 &      0.5 &     0.055 &       0.950 &             0.067 &      0.055 &        0.796 &              0.144 &     0.085 &       0.942 &             0.105 &     0.072 &       0.898 &             0.113 \\
# 11 &    3 &     6160.230 &  10000 &      1.0 &     0.055 &       0.950 &             0.067 &      0.055 &        0.909 &              0.081 &     0.064 &       0.949 &             0.077 &     0.060 &       0.933 &             0.078 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_e56ef_row0_col6, #T_e56ef_row1_col6, #T_e56ef_row2_col6, #T_e56ef_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_e56ef_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 78.2%, transparent 78.2%);
# }
# #T_e56ef_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_e56ef_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.4%, transparent 93.4%);
# }
# #T_e56ef_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.4%, transparent 95.4%);
# }
# #T_e56ef_row1_col12, #T_e56ef_row3_col6, #T_e56ef_row4_col6, #T_e56ef_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_e56ef_row1_col15, #T_e56ef_row2_col9, #T_e56ef_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.8%, transparent 97.8%);
# }
# #T_e56ef_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_e56ef_row2_col15, #T_e56ef_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_e56ef_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 42.4%, transparent 42.4%);
# }
# #T_e56ef_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_e56ef_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.3%, transparent 90.3%);
# }
# #T_e56ef_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 75.3%, transparent 75.3%);
# }
# #T_e56ef_row4_col12, #T_e56ef_row9_col6, #T_e56ef_row10_col6, #T_e56ef_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_e56ef_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.8%, transparent 93.8%);
# }
# #T_e56ef_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.3%, transparent 92.3%);
# }
# #T_e56ef_row5_col12, #T_e56ef_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_e56ef_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.4%, transparent 96.4%);
# }
# #T_e56ef_row6_col6, #T_e56ef_row7_col6, #T_e56ef_row8_col6, #T_e56ef_row8_col9, #T_e56ef_row8_col12, #T_e56ef_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_e56ef_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 86.7%, transparent 86.7%);
# }
# #T_e56ef_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_e56ef_row6_col15, #T_e56ef_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.6%, transparent 93.6%);
# }
# #T_e56ef_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_e56ef_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 53.7%, transparent 53.7%);
# }
# #T_e56ef_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.9%, transparent 88.9%);
# }
# #T_e56ef_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.9%, transparent 82.9%);
# }
# #T_e56ef_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_e56ef_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.2%, transparent 95.2%);
# }
# #T_e56ef_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.4%, transparent 97.4%);
# }
# </style>
# <table id="T_e56ef_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e56ef_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_e56ef_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e56ef_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_e56ef_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_e56ef_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_e56ef_row0_col5" class="data row0 col5" >0.055</td>
#       <td id="T_e56ef_row0_col6" class="data row0 col6" >0.948</td>
#       <td id="T_e56ef_row0_col7" class="data row0 col7" >0.067</td>
#       <td id="T_e56ef_row0_col8" class="data row0 col8" >0.055</td>
#       <td id="T_e56ef_row0_col9" class="data row0 col9" >0.748</td>
#       <td id="T_e56ef_row0_col10" class="data row0 col10" >0.182</td>
#       <td id="T_e56ef_row0_col11" class="data row0 col11" >0.099</td>
#       <td id="T_e56ef_row0_col12" class="data row0 col12" >0.960</td>
#       <td id="T_e56ef_row0_col13" class="data row0 col13" >0.117</td>
#       <td id="T_e56ef_row0_col14" class="data row0 col14" >0.080</td>
#       <td id="T_e56ef_row0_col15" class="data row0 col15" >0.896</td>
#       <td id="T_e56ef_row0_col16" class="data row0 col16" >0.125</td>
#       <td id="T_e56ef_row0_col17" class="data row0 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_e56ef_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_e56ef_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_e56ef_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_e56ef_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_e56ef_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_e56ef_row1_col5" class="data row1 col5" >0.055</td>
#       <td id="T_e56ef_row1_col6" class="data row1 col6" >0.948</td>
#       <td id="T_e56ef_row1_col7" class="data row1 col7" >0.067</td>
#       <td id="T_e56ef_row1_col8" class="data row1 col8" >0.055</td>
#       <td id="T_e56ef_row1_col9" class="data row1 col9" >0.913</td>
#       <td id="T_e56ef_row1_col10" class="data row1 col10" >0.078</td>
#       <td id="T_e56ef_row1_col11" class="data row1 col11" >0.064</td>
#       <td id="T_e56ef_row1_col12" class="data row1 col12" >0.954</td>
#       <td id="T_e56ef_row1_col13" class="data row1 col13" >0.075</td>
#       <td id="T_e56ef_row1_col14" class="data row1 col14" >0.060</td>
#       <td id="T_e56ef_row1_col15" class="data row1 col15" >0.938</td>
#       <td id="T_e56ef_row1_col16" class="data row1 col16" >0.075</td>
#       <td id="T_e56ef_row1_col17" class="data row1 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_e56ef_row2_col0" class="data row2 col0" >5,000</td>
#       <td id="T_e56ef_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_e56ef_row2_col2" class="data row2 col2" >1.0</td>
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.055 &       0.948 &             0.067 &      0.055 &        0.748 &              0.182 &     0.099 &       0.960 &             0.117 &     0.080 &       0.896 &             0.125 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.055 &       0.948 &             0.067 &      0.055 &        0.913 &              0.078 &     0.064 &       0.954 &             0.075 &     0.060 &       0.938 &             0.075 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.055 &       0.948 &             0.067 &      0.055 &        0.936 &              0.068 &     0.058 &       0.950 &             0.068 &     0.057 &       0.944 &             0.068 \\
# 3  &    3 &     3080.197 &   5000 &      0.2 &     0.071 &       0.947 &             0.085 &      0.070 &        0.406 &              1.261 &     0.308 &       0.959 &             0.373 &     0.222 &       0.866 &             0.436 \\
# 4  &    3 &     3080.197 &   5000 &      0.5 &     0.071 &       0.947 &             0.085 &      0.071 &        0.721 &              0.279 &     0.138 &       0.958 &             0.167 &     0.110 &       0.900 &             0.179 \\
# 5  &    3 &     3080.197 &   5000 &      1.0 &     0.071 &       0.947 &             0.085 &      0.071 &        0.883 &              0.123 &     0.092 &       0.952 &             0.110 &     0.082 &       0.924 &             0.112 \\
# 6  &    1 &    10000.000 &  10000 &      0.2 &     0.039 &       0.954 &             0.045 &      0.039 &        0.830 &              0.088 &     0.057 &       0.948 &             0.067 &     0.049 &       0.898 &             0.072 \\
# 7  &    1 &    10000.000 &  10000 &      0.5 &     0.039 &       0.954 &             0.045 &      0.039 &        0.936 &              0.049 &     0.043 &       0.955 &             0.049 &     0.041 &       0.945 &             0.049 \\
# 8  &    1 &    10000.000 &  10000 &      1.0 &     0.039 &       0.954 &             0.045 &      0.039 &        0.957 &              0.046 &     0.040 &       0.961 &             0.046 &     0.040 &       0.959 &             0.046 \\
# 9  &    3 &     6160.230 &  10000 &      0.2 &     0.050 &       0.951 &             0.060 &      0.050 &        0.514 &              0.543 &     0.157 &       0.946 &             0.195 &     0.116 &       0.853 &             0.232 \\
# 10 &    3 &     6160.230 &  10000 &      0.5 &     0.050 &       0.951 &             0.060 &      0.050 &        0.793 &              0.131 &     0.078 &       0.945 &             0.095 &     0.065 &       0.898 &             0.102 \\
# 11 &    3 &     6160.230 &  10000 &      1.0 &     0.050 &       0.951 &             0.060 &      0.050 &        0.911 &              0.073 &     0.058 &       0.952 &             0.070 &     0.054 &       0.934 &             0.071 \\
# \bottomrule
# \end{tabular}

# %%
print(f"""
For the same epsilon=0.2 and sensitivity=1, the noise scale
for gaussian: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="gaussian"):.3f}
for laplace: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="laplace"):.3f}
""")
# Out:
# For the same epsilon=0.2 and sensitivity=1, the noise scale
# for gaussian: 26.494
# for laplace: 5.000
