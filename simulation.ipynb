# %% [markdown]
# <a href="https://colab.research.google.com/github/miaojingang/private_ratio/blob/main/simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook has the simulation used in paper
#
# > Jingang Miao, Yiming Paul Li. (2021). Privacy Preserving Inference on the Ratio of Two Gaussians Using (Weighted) Sums. [arXiv:2110.15449](https://arxiv.org/abs/2110.15449).

# %%
#@title functions {form-width:"20%"}
import logging
import numpy as np
import pandas as pd
import functools
import warnings
warnings.filterwarnings('ignore')


def from_moments(m_s, m_y, v_s, v_y, v_ys, log_scale=False):
    """Gets mean and variance from moments of the means."""
    if log_scale:
        return np.log(m_s / m_y), (
            1. / m_s ** 2 * v_ys
            -2 * v_ys / m_y / m_s
            + v_y / m_y ** 2
        )
    else:
        return m_s / m_y, (
            1. / m_y ** 2 * v_s
            - 2 * m_s / m_y **3 * v_ys
            + m_s ** 2 / m_y** 4 * v_y
        )


def moments_from_sums(s, s2, y, y2, ys, w, w2):
    """Gets moments of the means from sums."""
    effective_n = w ** 2 / w2
    return (
        s / w, y / w,  # m_s, m_y
        (s2 / w - (s / w) ** 2) / effective_n,  # v_s
        (y2 / w - (y / w) ** 2) / effective_n,  # v_y
        (ys / w - y * s / w ** 2) / effective_n  # v_ys
    )

def from_sums(s, s2, y, y2, ys, w, w2, log_scale=False):
    """Gets mean and variance from sums."""
    moments = moments_from_sums(s, s2, y, y2, ys, w, w2)
    return from_moments(*moments, log_scale=log_scale)

def get_ci(m, v):
    half = 1.96 * np.sqrt(v)
    return m - half, m + half

def ci_length(ci):
    return ci[1] - ci[0]

def is_covered(ci, truth):
    return ci[0] < truth < ci[1]

def interval_score(ci, truth, alpha=0.05):
    # section 6.2 of https://sites.stat.washington.edu/raftery/Research/PDF/Gneiting2007jasa.pdf
    l, u = ci
    x = truth
    return (
        u - l  # length of ci
        + 2.0 / alpha * ((l - x) * (x < l) + (x - u) * (x > u))  # penalty for missing truth
    )

def get_noise_sd(Delta, epsilon, delta):
    return Delta * np.sqrt(2 * np.log(1.25 / delta)) / epsilon

def one_run_dp_sums(
    seed=0, n=1_000, u_w=1, B=200,
    epsilon=2, delta=1e-6, true=1.1, log_scale=False):
    # seed=0; n=1_000; u_w=1; B=200; epsilon=2; delta=1e-6; true=1.1; log_scale=False
    np.random.seed(seed)
    s = np.random.beta(2, 2, size=n)
    y = np.random.binomial(n=1, p=s/true, size=n)
    l_w = 1 / u_w
    w = np.random.exponential(1., size=n).clip(l_w, u_w)

    if log_scale:
        true = np.log(true)
        maybe_log = np.log
    else:
        maybe_log = lambda x: x

    # public version
    sum_s = s @ w
    sum_s2 = (s ** 2) @ w
    sum_y = sum_y2 = y @ w
    sum_ys = (y * s) @ w
    sum_w = w.sum()
    sum_w2 = (w ** 2).sum()
    m_p, v_p = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    ci_p = get_ci(m_p, v_p)
    length_p = ci_length(ci_p)
    covered_p = is_covered(ci_p, true)
    interval_score_p = interval_score(ci_p, true)

    # DP: add normal noise
    if u_w == 1.0:
        get_sd = functools.partial(
            get_noise_sd, epsilon=epsilon / 5, delta = delta / 5)
    else:
        get_sd = functools.partial(
            get_noise_sd, epsilon=epsilon / 6, delta = delta / 6)
    
    sum_s += np.random.normal(0, get_sd(u_w))
    sum_s2 += np.random.normal(0, get_sd(u_w))
    sum_y += np.random.normal(0, get_sd(u_w))
    sum_y2 = sum_y
    sum_ys += np.random.normal(0, get_sd(u_w))
    sum_w += np.random.normal(0, get_sd(u_w))
    if u_w == 1.0:
        sum_w2 = sum_w
    else:
        sum_w2 += np.random.normal(0, get_sd(u_w ** 2))
    # no correction
    m, v_nc = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    bias = m - true
    effective_n = w.sum() ** 2 / (w ** 2).sum()
    ci_nc = get_ci(m, v_nc)
    length_nc = ci_length(ci_nc)
    covered_nc = is_covered(ci_nc, true)
    interval_score_nc = interval_score(ci_nc, true)

    # monte carlo correction
    v_extra = ((maybe_log(
        (sum_s + np.random.normal(0, get_sd(u_w), size=B)) /
        (sum_y + np.random.normal(0, get_sd(u_w), size=B))
        ) - m
    ) ** 2).mean()
    
    ci_m = get_ci(m, v_nc + v_extra)
    length_m = ci_length(ci_m)
    covered_m = is_covered(ci_m, true)
    interval_score_m = interval_score(ci_m, true)

    # analytical correction
    m_s, m_y, v_s, v_y, v_sy = moments_from_sums(sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2)
    _, v_a = from_moments(
        m_s * sum_w, m_y * sum_w,
        v_s * sum_w ** 2 + get_sd(u_w) ** 2,
        v_y * sum_w ** 2 + get_sd(u_w) ** 2,
        v_sy * sum_w ** 2, log_scale=log_scale
    )
    ci_a = get_ci(m, v_a)
    length_a = ci_length(ci_a)
    covered_a = is_covered(ci_a, true)
    interval_score_a = interval_score(ci_a, true)

    return (
        n, epsilon, delta,
        u_w, effective_n,
        length_p, covered_p, interval_score_p,
        length_nc, covered_nc, interval_score_nc,
        length_m, covered_m, interval_score_m,
        length_a, covered_a, interval_score_a,
        bias
    )

def sim(
    show_styled_result=True,
    show_latex_result=True,
    **kwargs):
    res = (
        pd.DataFrame.from_records(
            (one_run_dp_sums(seed, n=n, u_w=u_w, epsilon=epsilon, **kwargs)
            for seed in range(1_000)
            for u_w in [1, 5]
            for n in [5000, 10_000]
            for epsilon in [0.5, 1., 4., 100.]
            ),
            columns = [
                "n", "epsilon", "delta", "u_w", "effective_n",
                "length_p", "coverage_p", "interval_score_p",
                "length_nc", "coverage_nc", "interval_score_nc",
                "length_m", "coverage_m", "interval_score_m",
                "length_a", "coverage_a", "interval_score_a",
                "bias"]
            )
        .groupby(["n", "u_w", "epsilon", "delta", ], as_index=False).mean()
    )
    if show_styled_result:
        display(
            res.style.hide_index()
            .format({
                "n": "{:,}",
                "epsilon": "{:.1f}", "effective_n": "{:,.0f}",
                "length_p": "{:.3f}", "coverage_p": "{:.3f}", "interval_score_p": "{:.3f}",
                "length_nc": "{:.3f}", "coverage_nc": "{:.3f}", "interval_score_nc": "{:.3f}",
                "length_m": "{:.3f}", "coverage_m": "{:.3f}", "interval_score_m": "{:.3f}",
                "length_a": "{:.3f}", "coverage_a": "{:.3f}", "interval_score_a": "{:.3f}",
                "bias": "{:.3f}"
            })
            .bar(subset=["coverage_p", "coverage_nc", "coverage_m", "coverage_a"],
                 color="lightgreen", vmin=0)
            .set_table_attributes("class='dataframe'")
        )
    if show_latex_result:
        cols = [
            "u_w", "effective_n",
            "n", "epsilon",
            "length_p", "coverage_p", "interval_score_p",
            "length_nc", "coverage_nc", "interval_score_nc",
            "length_m", "coverage_m", "interval_score_m",
            "length_a", "coverage_a", "interval_score_a",
        ]
        print(res[cols].round(3).to_latex())

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200)
# Out:
# <style type="text/css">
# #T_6d0e6_row0_col6, #T_6d0e6_row1_col6, #T_6d0e6_row1_col12, #T_6d0e6_row1_col15, #T_6d0e6_row2_col6, #T_6d0e6_row3_col6, #T_6d0e6_row4_col6, #T_6d0e6_row5_col6, #T_6d0e6_row5_col12, #T_6d0e6_row5_col15, #T_6d0e6_row6_col6, #T_6d0e6_row7_col6, #T_6d0e6_row9_col15, #T_6d0e6_row14_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_6d0e6_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 60.2%, transparent 60.2%);
# }
# #T_6d0e6_row0_col12, #T_6d0e6_row0_col15, #T_6d0e6_row4_col12, #T_6d0e6_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_6d0e6_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.1%, transparent 82.1%);
# }
# #T_6d0e6_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_6d0e6_row2_col12, #T_6d0e6_row2_col15, #T_6d0e6_row3_col9, #T_6d0e6_row3_col12, #T_6d0e6_row3_col15, #T_6d0e6_row14_col15, #T_6d0e6_row15_col9, #T_6d0e6_row15_col12, #T_6d0e6_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_6d0e6_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 14.9%, transparent 14.9%);
# }
# #T_6d0e6_row4_col15, #T_6d0e6_row6_col12, #T_6d0e6_row12_col6, #T_6d0e6_row13_col6, #T_6d0e6_row14_col6, #T_6d0e6_row15_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_6d0e6_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 32.7%, transparent 32.7%);
# }
# #T_6d0e6_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 81.3%, transparent 81.3%);
# }
# #T_6d0e6_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_6d0e6_row7_col12, #T_6d0e6_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_6d0e6_row8_col6, #T_6d0e6_row9_col6, #T_6d0e6_row10_col6, #T_6d0e6_row10_col12, #T_6d0e6_row10_col15, #T_6d0e6_row11_col6, #T_6d0e6_row11_col9, #T_6d0e6_row11_col12, #T_6d0e6_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_6d0e6_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 69.6%, transparent 69.6%);
# }
# #T_6d0e6_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.8%, transparent 97.8%);
# }
# #T_6d0e6_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_6d0e6_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.5%, transparent 91.5%);
# }
# #T_6d0e6_row9_col12, #T_6d0e6_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_6d0e6_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 18.6%, transparent 18.6%);
# }
# #T_6d0e6_row12_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_6d0e6_row12_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.9%, transparent 96.9%);
# }
# #T_6d0e6_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 38.6%, transparent 38.6%);
# }
# #T_6d0e6_row13_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.8%, transparent 96.8%);
# }
# #T_6d0e6_row13_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.5%, transparent 96.5%);
# }
# #T_6d0e6_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.5%, transparent 87.5%);
# }
# </style>
# <table id="T_6d0e6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d0e6_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_6d0e6_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_6d0e6_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_6d0e6_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_6d0e6_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_6d0e6_row0_col5" class="data row0 col5" >0.061</td>
#       <td id="T_6d0e6_row0_col6" class="data row0 col6" >0.947</td>
#       <td id="T_6d0e6_row0_col7" class="data row0 col7" >0.074</td>
#       <td id="T_6d0e6_row0_col8" class="data row0 col8" >0.061</td>
#       <td id="T_6d0e6_row0_col9" class="data row0 col9" >0.575</td>
#       <td id="T_6d0e6_row0_col10" class="data row0 col10" >0.459</td>
#       <td id="T_6d0e6_row0_col11" class="data row0 col11" >0.156</td>
#       <td id="T_6d0e6_row0_col12" class="data row0 col12" >0.949</td>
#       <td id="T_6d0e6_row0_col13" class="data row0 col13" >0.188</td>
#       <td id="T_6d0e6_row0_col14" class="data row0 col14" >0.156</td>
#       <td id="T_6d0e6_row0_col15" class="data row0 col15" >0.949</td>
#       <td id="T_6d0e6_row0_col16" class="data row0 col16" >0.186</td>
#       <td id="T_6d0e6_row0_col17" class="data row0 col17" >0.001</td>
#     </tr>
#     <tr>
#       <td id="T_6d0e6_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_6d0e6_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_6d0e6_row1_col2" class="data row1 col2" >1.0</td>
#       <td id="T_6d0e6_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_6d0e6_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_6d0e6_row1_col5" class="data row1 col5" >0.061</td>
#       <td id="T_6d0e6_row1_col6" class="data row1 col6" >0.947</td>
#       <td id="T_6d0e6_row1_col7" class="data row1 col7" >0.074</td>
#       <td id="T_6d0e6_row1_col8" class="data row1 col8" >0.061</td>
#       <td id="T_6d0e6_row1_col9" class="data row1 col9" >0.784</td>
#       <td id="T_6d0e6_row1_col10" class="data row1 col10" >0.155</td>
#       <td id="T_6d0e6_row1_col11" class="data row1 col11" >0.094</td>
#       <td id="T_6d0e6_row1_col12" class="data row1 col12" >0.947</td>
#       <td id="T_6d0e6_row1_col13" class="data row1 col13" >0.111</td>
#       <td id="T_6d0e6_row1_col14" class="data row1 col14" >0.094</td>
#       <td id="T_6d0e6_row1_col15" class="data row1 col15" >0.947</td>
#       <td id="T_6d0e6_row1_col16" class="data row1 col16" >0.111</td>
#       <td id="T_6d0e6_row1_col17" class="data row1 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_6d0e6_row2_col0" class="data row2 col0" >5,000</td>
#       <td id="T_6d0e6_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_6d0e6_row2_col2" class="data row2 col2" >4.0</td>
#       <td id="T_6d0e6_row2_col3" class="data row2 col3" >0.000001</td>
#       <td id="
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.5 &     0.061 &       0.947 &             0.074 &      0.061 &        0.575 &              0.459 &     0.156 &       0.949 &             0.188 &     0.156 &       0.949 &             0.186 \\
# 1  &    1 &     5000.000 &   5000 &      1.0 &     0.061 &       0.947 &             0.074 &      0.061 &        0.784 &              0.155 &     0.094 &       0.947 &             0.111 &     0.094 &       0.947 &             0.111 \\
# 2  &    1 &     5000.000 &   5000 &      4.0 &     0.061 &       0.947 &             0.074 &      0.061 &        0.936 &              0.077 &     0.064 &       0.948 &             0.076 &     0.064 &       0.948 &             0.076 \\
# 3  &    1 &     5000.000 &   5000 &    100.0 &     0.061 &       0.947 &             0.074 &      0.061 &        0.948 &              0.074 &     0.061 &       0.948 &             0.074 &     0.061 &       0.948 &             0.074 \\
# 4  &    5 &     2662.409 &   5000 &      0.5 &     0.084 &       0.947 &             0.101 &      0.086 &        0.142 &              5.318 &     0.989 &       0.949 &             1.135 &     0.903 &       0.946 &             1.058 \\
# 5  &    5 &     2662.409 &   5000 &      1.0 &     0.084 &       0.947 &             0.101 &      0.083 &        0.312 &              2.147 &     0.447 &       0.947 &             0.534 &     0.441 &       0.947 &             0.524 \\
# 6  &    5 &     2662.409 &   5000 &      4.0 &     0.084 &       0.947 &             0.101 &      0.084 &        0.776 &              0.243 &     0.136 &       0.946 &             0.165 &     0.136 &       0.949 &             0.164 \\
# 7  &    5 &     2662.409 &   5000 &    100.0 &     0.084 &       0.947 &             0.101 &      0.084 &        0.942 &              0.101 &     0.084 &       0.943 &             0.101 &     0.084 &       0.943 &             0.101 \\
# 8  &    1 &    10000.000 &  10000 &      0.5 &     0.043 &       0.955 &             0.049 &      0.043 &        0.665 &              0.196 &     0.083 &       0.934 &             0.104 &     0.084 &       0.935 &             0.104 \\
# 9  &    1 &    10000.000 &  10000 &      1.0 &     0.043 &       0.955 &             0.049 &      0.043 &        0.874 &              0.075 &     0.056 &       0.951 &             0.066 &     0.056 &       0.947 &             0.066 \\
# 10 &    1 &    10000.000 &  10000 &      4.0 &     0.043 &       0.955 &             0.049 &      0.043 &        0.951 &              0.049 &     0.044 &       0.955 &             0.049 &     0.044 &       0.955 &             0.049 \\
# 11 &    1 &    10000.000 &  10000 &    100.0 &     0.043 &       0.955 &             0.049 &      0.043 &        0.955 &              0.049 &     0.043 &       0.955 &             0.049 &     0.043 &       0.955 &             0.049 \\
# 12 &    5 &     5322.609 &  10000 &      0.5 &     0.059 &       0.946 &             0.072 &      0.058 &        0.178 &              2.764 &     0.442 &       0.932 &             0.556 &     0.435 &       0.925 &             0.556 \\
# 13 &    5 &     5322.609 &  10000 &      1.0 &     0.059 &       0.946 &             0.072 &      0.059 &        0.369 &              1.019 &     0.222 &       0.924 &             0.288 &     0.222 &       0.922 &             0.288 \\
# 14 &    5 &     5322.609 &  10000 &      4.0 &     0.059 &       0.946 &             0.072 &      0.059 &        0.836 &              0.119 &     0.080 &       0.947 &             0.098 &     0.080 &       0.948 &             0.098 \\
# 15 &    5 &     5322.609 &  10000 &    100.0 &     0.059 &       0.946 &             0.072 &      0.059 &        0.948 &              0.072 &     0.059 &       0.948 &             0.072 &     0.059 &       0.948 &             0.072 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200)
# Out:
# <style type="text/css">
# #T_5855d_row0_col6, #T_5855d_row1_col6, #T_5855d_row2_col6, #T_5855d_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_5855d_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 59.9%, transparent 59.9%);
# }
# #T_5855d_row0_col12, #T_5855d_row14_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_5855d_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.8%, transparent 92.8%);
# }
# #T_5855d_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
# }
# #T_5855d_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_5855d_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.2%, transparent 94.2%);
# }
# #T_5855d_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.8%, transparent 97.8%);
# }
# #T_5855d_row2_col12, #T_5855d_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# #T_5855d_row2_col15, #T_5855d_row5_col12, #T_5855d_row15_col9, #T_5855d_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_5855d_row3_col9, #T_5855d_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_5855d_row4_col6, #T_5855d_row5_col6, #T_5855d_row6_col6, #T_5855d_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_5855d_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 15.5%, transparent 15.5%);
# }
# #T_5855d_row4_col12, #T_5855d_row8_col6, #T_5855d_row9_col6, #T_5855d_row10_col6, #T_5855d_row11_col6, #T_5855d_row11_col9, #T_5855d_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_5855d_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.3%, transparent 91.3%);
# }
# #T_5855d_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 33.2%, transparent 33.2%);
# }
# #T_5855d_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.6%, transparent 90.6%);
# }
# #T_5855d_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 81.3%, transparent 81.3%);
# }
# #T_5855d_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_5855d_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.6%, transparent 94.6%);
# }
# #T_5855d_row7_col9, #T_5855d_row7_col15, #T_5855d_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_5855d_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.2%, transparent 97.2%);
# }
# #T_5855d_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 69.7%, transparent 69.7%);
# }
# #T_5855d_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.5%, transparent 96.5%);
# }
# #T_5855d_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.0%, transparent 92.0%);
# }
# #T_5855d_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.4%, transparent 91.4%);
# }
# #T_5855d_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_5855d_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.4%, transparent 96.4%);
# }
# #T_5855d_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_5855d_row10_col12, #T_5855d_row12_col6, #T_5855d_row13_col6, #T_5855d_row14_col6, #T_5855d_row15_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_5855d_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_5855d_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 18.8%, transparent 18.8%);
# }
# #T_5855d_row12_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.2%, transparent 96.2%);
# }
# #T_5855d_row12_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.8%, transparent 87.8%);
# }
# #T_5855d_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 38.4%, transparent 38.4%);
# }
# #T_5855d_row13_col12, #T_5855d_row14_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.4%, transparent 95.4%);
# }
# #T_5855d_row13_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.7%, transparent 88.7%);
# }
# #T_5855d_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.1%, transparent 87.1%);
# }
# #T_5855d_row15_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.5%, transparent 97.5%);
# }
# </style>
# <table id="T_5855d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5855d_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_5855d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5855d_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_5855d_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_5855d_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_5855d_row0_col5" class="data row0 col5" >0.055</td>
#       <td id="T_5855d_row0_col6" class="data row0 col6" >0.946</td>
#       <td id="T_5855d_row0_col7" class="data row0 col7" >0.067</td>
#       <td id="T_5855d_row0_col8" class="data row0 col8" >0.055</td>
#       <td id="T_5855d_row0_col9" class="data row0 col9" >0.571</td>
#       <td id="T_5855d_row0_col10" class="data row0 col10" >0.421</td>
#       <td id="T_5855d_row0_col11" class="data row0 col11" >0.141</td>
#       <td id="T_5855d_row0_col12" class="data row0 col12" >0.948</td>
#       <td id="T_5855d_row0_col13" class="data row0 col13" >0.171</td>
#       <td id="T_5855d_row0_col14" class="data row0 col14" >0.111</td>
#       <td id="T_5855d_row0_col15" class="data row0 col15" >0.884</td>
#       <td id="T_5855d_row0_col16" class="data row0 col16" >0.187</td>
#       <td id="T_5855d_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_5855d_row1_col0" class="d
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.5 &     0.055 &       0.946 &             0.067 &      0.055 &        0.571 &              0.421 &     0.141 &       0.948 &             0.171 &     0.111 &       0.884 &             0.187 \\
# 1  &    1 &     5000.000 &   5000 &      1.0 &     0.055 &       0.946 &             0.067 &      0.055 &        0.789 &              0.143 &     0.085 &       0.944 &             0.101 &     0.073 &       0.898 &             0.108 \\
# 2  &    1 &     5000.000 &   5000 &      4.0 &     0.055 &       0.946 &             0.067 &      0.055 &        0.932 &              0.070 &     0.057 &       0.945 &             0.069 &     0.056 &       0.942 &             0.070 \\
# 3  &    1 &     5000.000 &   5000 &    100.0 &     0.055 &       0.946 &             0.067 &      0.055 &        0.945 &              0.067 &     0.055 &       0.945 &             0.067 &     0.055 &       0.945 &             0.067 \\
# 4  &    5 &     2662.409 &   5000 &      0.5 &     0.075 &       0.943 &             0.092 &      0.074 &        0.148 &              4.925 &     0.822 &       0.967 &             0.912 &     0.592 &       0.870 &             1.115 \\
# 5  &    5 &     2662.409 &   5000 &      1.0 &     0.075 &       0.943 &             0.092 &      0.075 &        0.316 &              1.949 &     0.399 &       0.955 &             0.475 &     0.299 &       0.863 &             0.549 \\
# 6  &    5 &     2662.409 &   5000 &      4.0 &     0.075 &       0.943 &             0.092 &      0.075 &        0.775 &              0.223 &     0.123 &       0.949 &             0.150 &     0.104 &       0.902 &             0.159 \\
# 7  &    5 &     2662.409 &   5000 &    100.0 &     0.075 &       0.943 &             0.092 &      0.075 &        0.940 &              0.092 &     0.075 &       0.940 &             0.092 &     0.075 &       0.940 &             0.092 \\
# 8  &    1 &    10000.000 &  10000 &      0.5 &     0.039 &       0.953 &             0.045 &      0.039 &        0.664 &              0.180 &     0.076 &       0.933 &             0.095 &     0.062 &       0.877 &             0.106 \\
# 9  &    1 &    10000.000 &  10000 &      1.0 &     0.039 &       0.953 &             0.045 &      0.039 &        0.871 &              0.069 &     0.051 &       0.950 &             0.060 &     0.046 &       0.919 &             0.061 \\
# 10 &    1 &    10000.000 &  10000 &      4.0 &     0.039 &       0.953 &             0.045 &      0.039 &        0.951 &              0.045 &     0.040 &       0.954 &             0.045 &     0.039 &       0.952 &             0.045 \\
# 11 &    1 &    10000.000 &  10000 &    100.0 &     0.039 &       0.953 &             0.045 &      0.039 &        0.953 &              0.045 &     0.039 &       0.953 &             0.045 &     0.039 &       0.953 &             0.045 \\
# 12 &    5 &     5322.609 &  10000 &      0.5 &     0.053 &       0.941 &             0.066 &      0.053 &        0.179 &              2.511 &     0.395 &       0.930 &             0.499 &     0.293 &       0.837 &             0.641 \\
# 13 &    5 &     5322.609 &  10000 &      1.0 &     0.053 &       0.941 &             0.066 &      0.053 &        0.366 &              0.932 &     0.201 &       0.923 &             0.261 &     0.153 &       0.845 &             0.322 \\
# 14 &    5 &     5322.609 &  10000 &      4.0 &     0.053 &       0.941 &             0.066 &      0.053 &        0.830 &              0.110 &     0.072 &       0.948 &             0.089 &     0.064 &       0.909 &             0.093 \\
# 15 &    5 &     5322.609 &  10000 &    100.0 &     0.053 &       0.941 &             0.066 &      0.053 &        0.942 &              0.066 &     0.053 &       0.943 &             0.066 &     0.053 &       0.942 &             0.066 \\
# \bottomrule
# \end{tabular}
