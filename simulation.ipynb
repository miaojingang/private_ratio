# %% [markdown]
# <a href="https://colab.research.google.com/github/miaojingang/private_ratio/blob/main/simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook has the simulation used in paper
#
# > Jingang Miao, Yiming Paul Li. (2021). Privacy Preserving Inference on the Ratio of Two Gaussians Using Sums.

# %%
#@title functions {form-width:"20%"}
import logging
import numpy as np
import pandas as pd
import functools
import warnings
warnings.filterwarnings('ignore')


def from_moments(m_s, m_y, v_s, v_y, v_ys, log_scale=False):
    """Gets mean and variance from moments of the means."""
    if log_scale:
        # Equation after (1)
        return np.log(m_s / m_y), (
            1. / m_s ** 2 * v_s
            -2 * v_ys / m_y / m_s
            + v_y / m_y ** 2
        )
    else:
        # Equation (1)
        return m_s / m_y, (
            1. / m_y ** 2 * v_s
            - 2 * m_s / m_y **3 * v_ys
            + m_s ** 2 / m_y** 4 * v_y
        )

def moments_from_sums(s, s2, y, y2, ys, w, w2):
    """Gets moments of the means from sums."""
    effective_n = w ** 2 / w2
    # Equations (2) to (4)
    return (
        s / w, y / w,  # m_s, m_y
        (s2 / w - (s / w) ** 2) / effective_n,  # v_s
        (y2 / w - (y / w) ** 2) / effective_n,  # v_y
        (ys / w - y * s / w ** 2) / effective_n  # v_ys
    )

def from_sums(s, s2, y, y2, ys, w, w2, log_scale=False):
    """Gets point and variance estimates from sums."""
    moments = moments_from_sums(s, s2, y, y2, ys, w, w2)
    return from_moments(*moments, log_scale=log_scale)

def get_ci_maybe_bound_by_0(m, v, bound_by_0=False):
    half = 1.96 * np.sqrt(v)
    if bound_by_0:
        return np.maximum(m - half, 0), m + half
    return m - half, m + half

def ci_length(ci):
    return ci[1] - ci[0]

def is_covered(ci, truth):
    return ci[0] < truth < ci[1]

def interval_score(ci, truth, alpha=0.05):
    # section 6.2 of https://sites.stat.washington.edu/raftery/Research/PDF/Gneiting2007jasa.pdf
    l, u = ci
    x = truth
    return (
        u - l  # length of ci
        + 2.0 / alpha * ((l - x) * (x < l) + (x - u) * (x > u))  # penalty for missing truth
    )

def get_noise_scale(Delta, epsilon, delta, mechanism):
    if mechanism == "gaussian":
        return Delta * np.sqrt(2 * np.log(1.25 / delta)) / epsilon
    elif mechanism == "laplace":
        # does not depend on delta
        return Delta / epsilon

def get_variance_from_scale(scale, mechanism):
    if mechanism == "gaussian":
        return scale * scale
    elif mechanism == "laplace":
        return 2.0 * scale * scale

def one_run_dp_sums(
    seed=0, n=1_000, u_w=1, B=200,
    epsilon=2, delta=1e-6, true=1.1, log_scale=False, mechanism="gaussian"):
    # seed=0; n=1_000; u_w=1; B=200; epsilon=2; delta=1e-6; true=1.1; log_scale=False
    np.random.seed(seed + 12345)
    s = np.random.beta(2, 2, size=n)
    y = np.random.binomial(n=1, p=s/true, size=n)
    l_w = 1 / u_w
    w = np.random.exponential(1., size=n).clip(l_w, u_w)

    if log_scale:
        true = np.log(true)
        maybe_log = np.log
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=False)
    else:
        maybe_log = lambda x: x
        # ratio is non-negative
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=True)

    if mechanism == "gaussian":
        gen_noise = np.random.normal
    elif mechanism == "laplace":
        gen_noise = np.random.laplace
    else:
        raise ValueError("Only gaussian and laplace mechanisms are supported")
 
    # public version
    sum_s = s @ w
    sum_s2 = (s ** 2) @ w
    sum_y = sum_y2 = y @ w
    sum_ys = (y * s) @ w
    sum_w = w.sum()
    sum_w2 = (w ** 2).sum()
    m_p, v_p = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    ci_p = get_ci(m_p, v_p)
    length_p = ci_length(ci_p)
    covered_p = is_covered(ci_p, true)
    interval_score_p = interval_score(ci_p, true)

    # DP: add  noise
    if u_w == 1.0:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 5,
            delta = delta / 5, mechanism=mechanism)
    else:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 6,
            delta = delta / 6, mechanism=mechanism)
    get_variance = functools.partial(
        get_variance_from_scale, mechanism=mechanism)

    sum_s += gen_noise(0, get_scale(u_w))
    sum_s2 += gen_noise(0, get_scale(u_w))
    sum_y += gen_noise(0, get_scale(u_w))
    sum_y2 = sum_y
    sum_ys += gen_noise(0, get_scale(u_w))
    sum_w += gen_noise(0, get_scale(u_w))
    if u_w == 1.0:
        sum_w2 = sum_w
    else:
        sum_w2 += gen_noise(0, get_scale(u_w ** 2))
    # no correction
    m, v_nc = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    bias = m - true
    effective_n = w.sum() ** 2 / (w ** 2).sum()
    ci_nc = get_ci(m, v_nc)
    length_nc = ci_length(ci_nc)
    covered_nc = is_covered(ci_nc, true)
    interval_score_nc = interval_score(ci_nc, true)

    # monte carlo correction
    v_extra = ((maybe_log(
        (sum_s + gen_noise(0, get_scale(u_w), size=B)) /
        (sum_y + gen_noise(0, get_scale(u_w), size=B))
        ) - m
    ) ** 2).mean()
    
    ci_m = get_ci(m, v_nc + v_extra)
    length_m = ci_length(ci_m)
    covered_m = is_covered(ci_m, true)
    interval_score_m = interval_score(ci_m, true)

    # analytical correction
    m_s, m_y, v_s, v_y, v_ys = moments_from_sums(sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2)
   # switch from the moments of means to the moments of sums,
   # which doesn't change the ratio estimate and its standard error
    _, v_a = from_moments(
        m_s * sum_w,
        m_y * sum_w,
        v_s * sum_w ** 2 + get_variance(get_scale(u_w)),
        v_y * sum_w ** 2 + get_variance(get_scale(u_w)),
        v_ys * sum_w ** 2, log_scale=log_scale
    )
    ci_a = get_ci(m, v_a)
    length_a = ci_length(ci_a)
    covered_a = is_covered(ci_a, true)
    interval_score_a = interval_score(ci_a, true)

    return (
        n, epsilon, delta,
        u_w, effective_n,
        length_p, covered_p, interval_score_p,
        length_nc, covered_nc, interval_score_nc,
        length_m, covered_m, interval_score_m,
        length_a, covered_a, interval_score_a,
        bias
    )

def sim(
    show_styled_result=True,
    show_latex_result=True,
    **kwargs):
    res = (
        pd.DataFrame.from_records(
            (one_run_dp_sums(seed, n=n, u_w=u_w, epsilon=epsilon, **kwargs)
            for seed in range(1_000)
            for u_w in [1, 3]
            for n in [5_000,10_000]
            for epsilon in [0.2, 0.5, 1., 4.0]
            ),
            columns = [
                "n", "epsilon", "delta", "u_w", "effective_n",
                "length_p", "coverage_p", "interval_score_p",
                "length_nc", "coverage_nc", "interval_score_nc",
                "length_m", "coverage_m", "interval_score_m",
                "length_a", "coverage_a", "interval_score_a",
                "bias"]
            )
        .groupby(["n", "u_w", "epsilon", "delta", ], as_index=False).mean()
    )
    if show_styled_result:
        display(
            res.style.hide_index()
            .format({
                "n": "{:,}",
                "epsilon": "{:.1f}", "effective_n": "{:,.0f}",
                "length_p": "{:.3f}", "coverage_p": "{:.3f}", "interval_score_p": "{:.3f}",
                "length_nc": "{:.3f}", "coverage_nc": "{:.3f}", "interval_score_nc": "{:.3f}",
                "length_m": "{:.3f}", "coverage_m": "{:.3f}", "interval_score_m": "{:.3f}",
                "length_a": "{:.3f}", "coverage_a": "{:.3f}", "interval_score_a": "{:.3f}",
                "bias": "{:.3f}"
            })
            .bar(subset=["coverage_p", "coverage_nc", "coverage_m", "coverage_a"],
                 color="lightgreen", vmin=0)
            .set_table_attributes("class='dataframe'")
        )
    if show_latex_result:
        cols = [
            "u_w", "effective_n",
            "n", "epsilon",
            "length_p", "coverage_p", "interval_score_p",
            "length_nc", "coverage_nc", "interval_score_nc",
            "length_m", "coverage_m", "interval_score_m",
            "length_a", "coverage_a", "interval_score_a",
        ]
        print(res[cols].round(3).to_latex())

# %% [markdown]
# ## Gaussian mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="gaussian")
# Out:
# <style type="text/css">
# #T_3e680_row0_col6, #T_3e680_row1_col6, #T_3e680_row2_col6, #T_3e680_row3_col6, #T_3e680_row10_col12, #T_3e680_row14_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_3e680_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 24.4%, transparent 24.4%);
# }
# #T_3e680_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_3e680_row0_col15, #T_3e680_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_3e680_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 56.9%, transparent 56.9%);
# }
# #T_3e680_row1_col12, #T_3e680_row4_col6, #T_3e680_row5_col6, #T_3e680_row6_col6, #T_3e680_row7_col6, #T_3e680_row8_col6, #T_3e680_row8_col15, #T_3e680_row9_col6, #T_3e680_row9_col12, #T_3e680_row10_col6, #T_3e680_row11_col6, #T_3e680_row15_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_3e680_row1_col15, #T_3e680_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_3e680_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
# }
# #T_3e680_row2_col12, #T_3e680_row2_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_3e680_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_3e680_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_3e680_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_3e680_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 8.0%, transparent 8.0%);
# }
# #T_3e680_row4_col12, #T_3e680_row11_col15, #T_3e680_row14_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_3e680_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_3e680_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 21.7%, transparent 21.7%);
# }
# #T_3e680_row5_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_3e680_row5_col15, #T_3e680_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_3e680_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 42.1%, transparent 42.1%);
# }
# #T_3e680_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.7%, transparent 91.7%);
# }
# #T_3e680_row7_col12, #T_3e680_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_3e680_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_3e680_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 37.5%, transparent 37.5%);
# }
# #T_3e680_row8_col12, #T_3e680_row11_col9, #T_3e680_row12_col6, #T_3e680_row12_col12, #T_3e680_row13_col6, #T_3e680_row13_col15, #T_3e680_row14_col6, #T_3e680_row15_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_3e680_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 74.0%, transparent 74.0%);
# }
# #T_3e680_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.1%, transparent 92.1%);
# }
# #T_3e680_row10_col15, #T_3e680_row13_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_3e680_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 13.3%, transparent 13.3%);
# }
# #T_3e680_row12_col15, #T_3e680_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_3e680_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 34.1%, transparent 34.1%);
# }
# #T_3e680_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 58.7%, transparent 58.7%);
# }
# #T_3e680_row15_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.3%, transparent 96.3%);
# }
# </style>
# <table id="T_3e680_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e680_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_3e680_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_3e680_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_3e680_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_3e680_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_3e680_row0_col5" class="data row0 col5" >0.061</td>
#       <td id="T_3e680_row0_col6" class="data row0 col6" >0.951</td>
#       <td id="T_3e680_row0_col7" class="data row0 col7" >0.073</td>
#       <td id="T_3e680_row0_col8" class="data row0 col8" >0.060</td>
#       <td id="T_3e680_row0_col9" class="data row0 col9" >0.231</td>
#       <td id="T_3e680_row0_col10" class="data row0 col10" >2.074</td>
#       <td id="T_3e680_row0_col11" class="data row0 col11" >0.370</td>
#       <td id="T_3e680_row0_col12" class="data row0 col12" >0.945</td>
#       <td id="T_3e680_row0_col13" class="data row0 col13" >0.452</td>
#       <td id="T_3e680_row0_col14" class="data row0 col14" >0.367</td>
#       <td id="T_3e680_row0_col15" class="data row0 col15" >0.943</td>
#       <td id="T_3e680_row0_col16" class="data row0 col16" >0.451</td>
#       <td id="T_3e680_row0_col17" class="data row0 col17" >0.003</td>
#     </tr>
#     <tr>
#       <td id="T_3e680_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_3e680_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_3e680_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_3e680_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_3e680_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_3e680_row1_col5" class="data row1 col5" >0.061</td>
#       <td id="T_3e680_row1_col6" class="data row1 col6" >0.951</td>
#       <td id="T_3e680_row1_col7" class="data row1 col7" >0.073</td>
#       <td id="T_3e680_row1_col8" class="data row1 col8" >0.061</td>
#       <td id="T_3e680_row1_col9" class="data row1 col9" >0.538</td>
#       <td id="T_3e680_row1_col10" class="data row1 col10" >0.489</td>
#       <td id="T_3e680_row1_col11" class="data
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.061 &       0.951 &             0.073 &      0.060 &        0.231 &              2.074 &     0.370 &       0.945 &             0.452 &     0.367 &       0.943 &             0.451 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.061 &       0.951 &             0.073 &      0.061 &        0.538 &              0.489 &     0.156 &       0.952 &             0.191 &     0.156 &       0.946 &             0.192 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.061 &       0.951 &             0.073 &      0.061 &        0.782 &              0.158 &     0.094 &       0.948 &             0.115 &     0.094 &       0.950 &             0.116 \\
row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 24.6%, transparent 24.6%);
# }
# #T_bf148_row0_col12, #T_bf148_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_bf148_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.5%, transparent 96.5%);
# }
# #T_bf148_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 56.6%, transparent 56.6%);
# }
# #T_bf148_row1_col12, #T_bf148_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_bf148_row1_col15, #T_bf148_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.4%, transparent 97.4%);
# }
# #T_bf148_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.9%, transparent 82.9%);
# }
# #T_bf148_row2_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_bf148_row3_col9, #T_bf148_row7_col12, #T_bf148_row14_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_bf148_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.8%, transparent 96.8%);
# }
# #T_bf148_row4_col6, #T_bf148_row5_col6, #T_bf148_row6_col6, #T_bf148_row7_col6, #T_bf148_row8_col6, #T_bf148_row9_col6, #T_bf148_row10_col6, #T_bf148_row10_col12, #T_bf148_row11_col6, #T_bf148_row13_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_bf148_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 7.9%, transparent 7.9%);
# }
# #T_bf148_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.3%, transparent 95.3%);
# }
# #T_bf148_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 21.8%, transparent 21.8%);
# }
# #T_bf148_row5_col12, #T_bf148_row6_col12, #T_bf148_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_bf148_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.6%, transparent 96.6%);
# }
# #T_bf148_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 41.8%, transparent 41.8%);
# }
# #T_bf148_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.7%, transparent 96.7%);
# }
# #T_bf148_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.4%, transparent 91.4%);
# }
# #T_bf148_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.5%, transparent 97.5%);
# }
# #T_bf148_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 37.6%, transparent 37.6%);
# }
# #T_bf148_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_bf148_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_bf148_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 74.2%, transparent 74.2%);
# }
# #T_bf148_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_bf148_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.3%, transparent 97.3%);
# }
# #T_bf148_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.4%, transparent 92.4%);
# }
# #T_bf148_row11_col12, #T_bf148_row12_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_bf148_row12_col6, #T_bf148_row13_col6, #T_bf148_row14_col6, #T_bf148_row15_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_bf148_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 13.0%, transparent 13.0%);
# }
# #T_bf148_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 34.0%, transparent 34.0%);
# }
# #T_bf148_row13_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_bf148_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 58.8%, transparent 58.8%);
# }
# #T_bf148_row14_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_bf148_row15_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.3%, transparent 96.3%);
# }
# #T_bf148_row15_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_bf148_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# </style>
# <table id="T_bf148_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf148_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_bf148_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_bf148_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_bf148_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_bf148_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_bf148_row0_col5" class="data row0 col5" >0.055</td>
#       <td id="T_bf148_row0_col6" class="data row0 col6" >0.953</td>
#       <td id="T_bf148_row0_col7" class="data row0 col7" >0.066</td>
#       <td id="T_bf148_row0_col8" class="data row0 col8" >0.055</td>
#       <td id="T_bf148_row0_col9" class="data row0 col9" >0.232</td>
#       <td id="T_bf148_row0_col10" class="data row0 col10" >1.882</td>
#       <td id="T_bf148_row0_col11" class="data row0 col11" >0.333</td>
#       <td id="T_bf148_row0_col12" class="data row0 col12" >0.944</td>
#       <td id="T_bf148_row0_col13" class="data row0 col13" >0.405</td>
#       <td id="T_bf148_row0_col14" class="data row0 col14" >0.332</td>
#       <td id="T_bf148_row0_col15" class="data row0 col15" >0.941</td>
#       <td id="T_bf148_row0_col16" class="data row0 col16" >0.406</td>
#       <td id="T_bf148_row0_col17" class="data row0 col17" >-0.001</td>
#     </tr>
#     <tr>
#       <td id="T_bf148_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_bf148_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_b
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0
\\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Laplace mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_32963_row0_col6, #T_32963_row1_col6, #T_32963_row2_col6, #T_32963_row3_col6, #T_32963_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_32963_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 76.7%, transparent 76.7%);
# }
# #T_32963_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# #T_32963_row0_col15, #T_32963_row5_col12, #T_32963_row12_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_32963_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.1%, transparent 94.1%);
# }
# #T_32963_row1_col12, #T_32963_row1_col15, #T_32963_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_32963_row2_col9, #T_32963_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_32963_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_32963_row2_col15, #T_32963_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_32963_row3_col9, #T_32963_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_32963_row3_col12, #T_32963_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_32963_row3_col15, #T_32963_row11_col15, #T_32963_row13_col12, #T_32963_row13_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_32963_row4_col6, #T_32963_row5_col6, #T_32963_row6_col6, #T_32963_row7_col6, #T_32963_row8_col6, #T_32963_row9_col6, #T_32963_row9_col12, #T_32963_row10_col6, #T_32963_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_32963_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 43.7%, transparent 43.7%);
# }
# #T_32963_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_32963_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_32963_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 73.4%, transparent 73.4%);
# }
# #T_32963_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 89.6%, transparent 89.6%);
# }
# #T_32963_row6_col12, #T_32963_row12_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.8%, transparent 97.8%);
# }
# #T_32963_row6_col15, #T_32963_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
# }
# #T_32963_row7_col9, #T_32963_row7_col15, #T_32963_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_32963_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.1%, transparent 87.1%);
# }
# #T_32963_row10_col9, #T_32963_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_32963_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_32963_row12_col6, #T_32963_row13_col6, #T_32963_row14_col6, #T_32963_row14_col12, #T_32963_row14_col15, #T_32963_row15_col6, #T_32963_row15_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_32963_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 54.9%, transparent 54.9%);
# }
# #T_32963_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
# }
# #T_32963_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.5%, transparent 95.5%);
# }
# #T_32963_row15_col12, #T_32963_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# </style>
# <table id="T_32963_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_32963_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_32963_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_32963_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_32963_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_32963_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_32963_row0_col5" class="data row0 col5" >0.061</td>
#       <td id="T_32963_row0_col6" class="data row0 col6" >0.951</td>
#       <td id="T_32963_row0_col7" class="data row0 col7" >0.073</td>
#       <td id="T_32963_row0_col8" class="data row0 col8" >0.061</td>
#       <td id="T_32963_row0_col9" class="data row0 col9" >0.730</td>
#       <td id="T_32963_row0_col10" class="data row0 col10" >0.238</td>
#       <td id="T_32963_row0_col11" class="data row0 col11" >0.109</td>
#       <td id="T_32963_row0_col12" class="data row0 col12" >0.937</td>
#       <td id="T_32963_row0_col13" class="data row0 col13" >0.149</td>
#       <td id="T_32963_row0_col14" class="data row0 col14" >0.109</td>
#       <td id="T_32963_row0_col15" class="data row0 col15" >0.940</td>
#       <td id="T_32963_row0_col16" class="data row0 col16" >0.147</td>
#       <td id="T_32963_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T
# 10 &    1 &    10000.000 &  10000 &      1.0 &     0.043 &       0.949 &             0.050 &      0.043 &        0.946 &              0.052 &     0.044 &       0.953 &             0.052 &     0.044 &       0.952 &             0.052 \\
# 11 &    1 &    10000.000 &  10000 &      4.0 &     0.043 &       0.949 &             0.050 &      0.043 &        0.949 &              0.050 &     0.043 &       0.950 &             0.050 &     0.043 &       0.950 &             0.050 \\
# 12 &    3 &     6160.779 &  10000 &      0.2 &     0.055 &       0.953 &             0.063 &      0.055 &        0.523 &              0.618 &     0.173 &       0.938 &             0.226 &     0.173 &       0.940 &             0.226 \\
# 13 &    3 &     6160.779 &  10000 &      0.5 &     0.055 &       0.953 &             0.063 &      0.055 &        0.788 &              0.146 &     0.085 &       0.952 &             0.104 &     0.085 &       0.950 &             0.104 \\
# 14 &    3 &     6160.779 &  10000 &      1.0 &     0.055 &       0.953 &             0.063 &      0.055 &        0.909 &              0.076 &     0.064 &       0.959 &             0.074 &     0.064 &       0.957 &             0.074 \\
# 15 &    3 &     6160.779 &  10000 &      4.0 &     0.055 &       0.953 &             0.063 &      0.055 &        0.952 &              0.063 &     0.056 &       0.958 &             0.063 &     0.056 &       0.956 &             0.063 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_84325_row0_col6, #T_84325_row1_col6, #T_84325_row2_col6, #T_84325_row3_col6, #T_84325_row14_col12, #T_84325_row14_col15, #T_84325_row15_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_84325_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 76.6%, transparent 76.6%);
# }
# #T_84325_row0_col12, #T_84325_row4_col15, #T_84325_row6_col12, #T_84325_row9_col9, #T_84325_row12_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_84325_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_84325_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.6%, transparent 94.6%);
# }
# #T_84325_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_84325_row1_col15, #T_84325_row7_col12, #T_84325_row8_col12, #T_84325_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_84325_row2_col9, #T_84325_row5_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_84325_row2_col12, #T_84325_row2_col15, #T_84325_row11_col15, #T_84325_row13_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_84325_row3_col9, #T_84325_row4_col6, #T_84325_row5_col6, #T_84325_row6_col6, #T_84325_row7_col6, #T_84325_row8_col6, #T_84325_row9_col6, #T_84325_row9_col12, #T_84325_row10_col6, #T_84325_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_84325_row3_col12, #T_84325_row3_col15, #T_84325_row13_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_84325_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 43.2%, transparent 43.2%);
# }
# #T_84325_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.4%, transparent 97.4%);
# }
# #T_84325_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 73.0%, transparent 73.0%);
# }
# #T_84325_row5_col15, #T_84325_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_84325_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 89.6%, transparent 89.6%);
# }
# #T_84325_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_84325_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_84325_row8_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 87.1%, transparent 87.1%);
# }
# #T_84325_row9_col15, #T_84325_row10_col12, #T_84325_row10_col15, #T_84325_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_84325_row10_col9, #T_84325_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_84325_row12_col6, #T_84325_row13_col6, #T_84325_row14_col6, #T_84325_row15_col6, #T_84325_row15_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_84325_row12_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 55.1%, transparent 55.1%);
# }
# #T_84325_row12_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.7%, transparent 97.7%);
# }
# #T_84325_row13_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
# }
# #T_84325_row14_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.5%, transparent 95.5%);
# }
# #T_84325_row15_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# </style>
# <table id="T_84325_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84325_row0_col0" class="data row0 col0" >5,000</td>
#       <td id="T_84325_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_84325_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_84325_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_84325_row0_col4" class="data row0 col4" >5,000</td>
#       <td id="T_84325_row0_col5" class="data row0 col5" >0.055</td>
#       <td id="T_84325_row0_col6" class="data row0 col6" >0.953</td>
#       <td id="T_84325_row0_col7" class="data row0 col7" >0.066</td>
#       <td id="T_84325_row0_col8" class="data row0 col8" >0.055</td>
#       <td id="T_84325_row0_col9" class="data row0 col9" >0.730</td>
#       <td id="T_84325_row0_col10" class="data row0 col10" >0.217</td>
#       <td id="T_84325_row0_col11" class="data row0 col11" >0.099</td>
#       <td id="T_84325_row0_col12" class="data row0 col12" >0.938</td>
#       <td id="T_84325_row0_col13" class="data row0 col13" >0.135</td>
#       <td id="T_84325_row0_col14" class="data row0 col14" >0.099</td>
#       <td id="T_84325_row0_col15" class="data row0 col15" >0.943</td>
#       <td id="T_84325_row0_col16" class="data row0 col16" >0.134</td>
#       <td id="T_84325_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_84325_row1_col0" class="data row1 col0" >5,000</td>
#       <td id="T_84325_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_84325_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_84325_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_84325_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_84325_row1_col5" class="data row1 col5" >0.055</td>
#       <td id="T_84325_row1_col6" class="data row1 col6" >0.953</td>
#       <td id="T_84325_row1_col7" class="data row1 col7" >0.066</td>
#       <td id="T_84325_row1_col8" class="data row1 col8" >0.055</td>
#       <td id="T_84325_row1_col9" class="data row1 col9" >0.902</td>
#       <td id="T_84325_row1_col10" class="data row1 col10" >0.086</td>
#       <td id="T_84325_row1_col11" class="data row1 col11" >0.064</td>
#       <td id="T_84325_row1_col12" class="data row1 col12" >0.946</td>
#       <td id="T_84325_row1_col13" class="data row1 col13" >0.081</td>
#       <td id="T_84325_row1_col14" class="data row1 col14" >0.065</td>
#       <td id="T_84325_row1_col15" class="data row1 col15" >0.946</td>
#       <td id="T_84325_row1_col16" class="data row1 col16" >0.081</td>
#       <td id="T_84325_row1_col17" class="data row1 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_84325_row2_col0" class="data row2 col0" >5,000</td>
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &     5000.000 &   5000 &      0.2 &     0.055 &       0.953 &             0.066 &      0.055 &        0.730 &              0.217 &     0.099 &       0.938 &             0.135 &     0.099 &       0.943 &             0.134 \\
# 1  &    1 &     5000.000 &   5000 &      0.5 &     0.055 &       0.953 &             0.066 &      0.055 &        0.902 &              0.086 &     0.064 &       0.946 &             0.081 &     0.065 &       0.946 &             0.081 \\
# 2  &    1 &     5000.000 &   5000 &      1.0 &     0.055 &       0.953 &             0.066 &      0.055 &        0.936 &              0.071 &     0.058 &       0.950 &             0.070 &     0.058 &       0.949 &             0.070 \\
# 3  &    1 &     5000.000 &   5000 &      4.0 &     0.055 &       0.953 &             0.066 &      0.055 &        0.948 &              0.067 &     0.056 &       0.951 &             0.067 &     0.056 &       0.950 &             0.067 \\
# 4  &    3 &     3081.532 &   5000 &      0.2 &     0.071 &       0.948 &             0.085 &      0.070 &        0.412 &              1.365 &     0.308 &       0.933 &             0.432 &     0.307 &       0.937 &             0.426 \\
# 5  &    3 &     3081.532 &   5000 &      0.5 &     0.071 &       0.948 &             0.085 &      0.071 &        0.696 &              0.329 &     0.138 &       0.941 &             0.184 &     0.138 &       0.944 &             0.183 \\
# 6  &    3 &     3081.532 &   5000 &      1.0 &     0.071 &       0.948 &             0.085 &      0.071 &        0.854 &              0.136 &     0.092 &       0.938 &             0.116 &     0.092 &       0.938 &             0.116 \\
# 7  &    3 &     3081.532 &   5000 &      4.0 &     0.071 &       0.948 &             0.085 &      0.071 &        0.940 &              0.087 &     0.072 &       0.947 &             0.087 &     0.072 &       0.947 &             0.087 \\
# 8  &    1 &    10000.000 &  10000 &      0.2 &     0.039 &       0.948 &             0.046 &      0.039 &        0.830 &              0.089 &     0.057 &       0.947 &             0.070 &     0.057 &       0.946 &             0.071 \\
# 9  &    1 &    10000.000 &  10000 &      0.5 &     0.039 &       0.948 &             0.046 &      0.039 &        0.933 &              0.051 &     0.043 &       0.953 &             0.050 &     0.043 &       0.953 &             0.050 \\
# 10 &    1 &    10000.000 &  10000 &      1.0 &     0.039 &       0.948 &             0.046 &      0.039 &        0.944 &              0.047 &     0.040 &       0.954 &             0.047 &     0.040 &       0.953 &             0.047 \\
# 11 &    1 &    10000.000 &  10000 &      4.0 &     0.039 &       0.948 &             0.046 &      0.039 &        0.949 &              0.046 &     0.039 &       0.949 &             0.046 &     0.039 &       0.949 &             0.046 \\
# 12 &    3 &     6160.779 &  10000 &      0.2 &     0.050 &       0.951 &             0.057 &      0.050 &        0.525 &              0.561 &     0.157 &       0.936 &             0.207 &     0.157 &       0.937 &             0.207 \\
# 13 &    3 &     6160.779 &  10000 &      0.5 &     0.050 &       0.951 &             0.057 &      0.050 &        0.789 &              0.133 &     0.078 &       0.950 &             0.095 &     0.078 &       0.950 &             0.095 \\
# 14 &    3 &     6160.779 &  10000 &      1.0 &     0.050 &       0.951 &             0.057 &      0.050 &        0.910 &              0.070 &     0.058 &       0.958 &             0.067 &     0.058 &       0.957 &             0.067 \\
# 15 &    3 &     6160.779 &  10000 &      4.0 &     0.050 &       0.951 &             0.057 &      0.050 &        0.953 &              0.057 &     0.050 &       0.956 &             0.058 &     0.050 &       0.956 &             0.058 \\
# \bottomrule
# \end{tabular}

# %%
print(f"""
For the same epsilon=0.2 and sensitivity=1, the variance of noise
for gaussian: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="gaussian") ** 2:.3f}
for laplace: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="laplace") ** 2 * 2:.3f}
""")
# Out:
# For the same epsilon=0.2 and sensitivity=1, the variance of noise
# for gaussian: 701.933
# for laplace: 50.000
