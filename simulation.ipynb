# %% [markdown]
# <a href="https://colab.research.google.com/github/miaojingang/private_ratio/blob/main/simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook has the simulation used in paper
#
# > Jingang Miao, Yiming Paul Li. (2021). Privacy Preserving Inference on the Ratio of Two Gaussians Using (Weighted) Sums. [arXiv:2110.15449](https://arxiv.org/abs/2110.15449).

# %%
#@title functions {form-width:"20%"}
import logging
import numpy as np
import pandas as pd
import functools
import warnings
warnings.filterwarnings('ignore')


def from_moments(m_s, m_y, v_s, v_y, v_ys, log_scale=False):
    """Gets mean and variance from moments of the means."""
    if log_scale:
        return np.log(m_s / m_y), (
            1. / m_s ** 2 * v_ys
            -2 * v_ys / m_y / m_s
            + v_y / m_y ** 2
        )
    else:
        return m_s / m_y, (
            1. / m_y ** 2 * v_s
            - 2 * m_s / m_y **3 * v_ys
            + m_s ** 2 / m_y** 4 * v_y
        )

def moments_from_sums(s, s2, y, y2, ys, w, w2):
    """Gets moments of the means from sums."""
    effective_n = w ** 2 / w2
    return (
        s / w, y / w,  # m_s, m_y
        (s2 / w - (s / w) ** 2) / effective_n,  # v_s
        (y2 / w - (y / w) ** 2) / effective_n,  # v_y
        (ys / w - y * s / w ** 2) / effective_n  # v_ys
    )

def from_sums(s, s2, y, y2, ys, w, w2, log_scale=False):
    """Gets mean and variance from sums."""
    moments = moments_from_sums(s, s2, y, y2, ys, w, w2)
    return from_moments(*moments, log_scale=log_scale)

def get_ci_maybe_bound_by_0(m, v, bound_by_0=False):
    half = 1.96 * np.sqrt(v)
    if bound_by_0:
        return np.maximum(m - half, 0), m + half
    return m - half, m + half

def ci_length(ci):
    return ci[1] - ci[0]

def is_covered(ci, truth):
    return ci[0] < truth < ci[1]

def interval_score(ci, truth, alpha=0.05):
    # section 6.2 of https://sites.stat.washington.edu/raftery/Research/PDF/Gneiting2007jasa.pdf
    l, u = ci
    x = truth
    return (
        u - l  # length of ci
        + 2.0 / alpha * ((l - x) * (x < l) + (x - u) * (x > u))  # penalty for missing truth
    )

def get_noise_scale(Delta, epsilon, delta, mechanism):
    if mechanism == "gaussian":
        return Delta * np.sqrt(2 * np.log(1.25 / delta)) / epsilon
    elif mechanism == "laplace":
        return Delta / epsilon

def one_run_dp_sums(
    seed=0, n=1_000, u_w=1, B=200,
    epsilon=2, delta=1e-6, true=1.1, log_scale=False, mechanism="gaussian"):
    # seed=0; n=1_000; u_w=1; B=200; epsilon=2; delta=1e-6; true=1.1; log_scale=False
    np.random.seed(seed)
    s = np.random.beta(2, 2, size=n)
    y = np.random.binomial(n=1, p=s/true, size=n)
    l_w = 1 / u_w
    w = np.random.exponential(1., size=n).clip(l_w, u_w)

    if log_scale:
        true = np.log(true)
        maybe_log = np.log
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=False)
    else:
        maybe_log = lambda x: x
        # ratio is non-negative
        get_ci = functools.partial(get_ci_maybe_bound_by_0, bound_by_0=True)

    if mechanism == "gaussian":
        gen_noise = np.random.normal
    elif mechanism == "laplace":
        gen_noise = np.random.laplace
    else:
        raise ValueError("Only gaussian and laplace mechanisms are supported")
 
    # public version
    sum_s = s @ w
    sum_s2 = (s ** 2) @ w
    sum_y = sum_y2 = y @ w
    sum_ys = (y * s) @ w
    sum_w = w.sum()
    sum_w2 = (w ** 2).sum()
    m_p, v_p = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    ci_p = get_ci(m_p, v_p)
    length_p = ci_length(ci_p)
    covered_p = is_covered(ci_p, true)
    interval_score_p = interval_score(ci_p, true)

    # DP: add normal noise
    if u_w == 1.0:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 5,
            delta = delta / 5, mechanism=mechanism)
    else:
        get_scale = functools.partial(
            get_noise_scale, epsilon=epsilon / 6,
            delta = delta / 6, mechanism=mechanism)
    
    sum_s += gen_noise(0, get_scale(u_w))
    sum_s2 += gen_noise(0, get_scale(u_w))
    sum_y += gen_noise(0, get_scale(u_w))
    sum_y2 = sum_y
    sum_ys += gen_noise(0, get_scale(u_w))
    sum_w += gen_noise(0, get_scale(u_w))
    if u_w == 1.0:
        sum_w2 = sum_w
    else:
        sum_w2 += gen_noise(0, get_scale(u_w ** 2))
    # no correction
    m, v_nc = from_sums(
        sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2, log_scale=log_scale
    )
    bias = m - true
    effective_n = w.sum() ** 2 / (w ** 2).sum()
    ci_nc = get_ci(m, v_nc)
    length_nc = ci_length(ci_nc)
    covered_nc = is_covered(ci_nc, true)
    interval_score_nc = interval_score(ci_nc, true)

    # monte carlo correction
    v_extra = ((maybe_log(
        (sum_s + gen_noise(0, get_scale(u_w), size=B)) /
        (sum_y + gen_noise(0, get_scale(u_w), size=B))
        ) - m
    ) ** 2).mean()
    
    ci_m = get_ci(m, v_nc + v_extra)
    length_m = ci_length(ci_m)
    covered_m = is_covered(ci_m, true)
    interval_score_m = interval_score(ci_m, true)

    # analytical correction
    m_s, m_y, v_s, v_y, v_sy = moments_from_sums(sum_s, sum_s2, sum_y, sum_y2,
        sum_ys, sum_w, sum_w2)
    _, v_a = from_moments(
        m_s * sum_w, m_y * sum_w,
        v_s * sum_w ** 2 + get_scale(u_w) ** 2,
        v_y * sum_w ** 2 + get_scale(u_w) ** 2,
        v_sy * sum_w ** 2, log_scale=log_scale
    )
    ci_a = get_ci(m, v_a)
    length_a = ci_length(ci_a)
    covered_a = is_covered(ci_a, true)
    interval_score_a = interval_score(ci_a, true)

    return (
        n, epsilon, delta,
        u_w, effective_n,
        length_p, covered_p, interval_score_p,
        length_nc, covered_nc, interval_score_nc,
        length_m, covered_m, interval_score_m,
        length_a, covered_a, interval_score_a,
        bias
    )

def sim(
    show_styled_result=True,
    show_latex_result=True,
    **kwargs):
    res = (
        pd.DataFrame.from_records(
            (one_run_dp_sums(seed, n=n, u_w=u_w, epsilon=epsilon, **kwargs)
            for seed in range(1_000)
            for u_w in [1, 3]
            for n in [20_000, 50_000]
            for epsilon in [0.2, 0.5, 1.]
            ),
            columns = [
                "n", "epsilon", "delta", "u_w", "effective_n",
                "length_p", "coverage_p", "interval_score_p",
                "length_nc", "coverage_nc", "interval_score_nc",
                "length_m", "coverage_m", "interval_score_m",
                "length_a", "coverage_a", "interval_score_a",
                "bias"]
            )
        .groupby(["n", "u_w", "epsilon", "delta", ], as_index=False).mean()
    )
    if show_styled_result:
        display(
            res.style.hide_index()
            .format({
                "n": "{:,}",
                "epsilon": "{:.1f}", "effective_n": "{:,.0f}",
                "length_p": "{:.3f}", "coverage_p": "{:.3f}", "interval_score_p": "{:.3f}",
                "length_nc": "{:.3f}", "coverage_nc": "{:.3f}", "interval_score_nc": "{:.3f}",
                "length_m": "{:.3f}", "coverage_m": "{:.3f}", "interval_score_m": "{:.3f}",
                "length_a": "{:.3f}", "coverage_a": "{:.3f}", "interval_score_a": "{:.3f}",
                "bias": "{:.3f}"
            })
            .bar(subset=["coverage_p", "coverage_nc", "coverage_m", "coverage_a"],
                 color="lightgreen", vmin=0)
            .set_table_attributes("class='dataframe'")
        )
    if show_latex_result:
        cols = [
            "u_w", "effective_n",
            "n", "epsilon",
            "length_p", "coverage_p", "interval_score_p",
            "length_nc", "coverage_nc", "interval_score_nc",
            "length_m", "coverage_m", "interval_score_m",
            "length_a", "coverage_a", "interval_score_a",
        ]
        print(res[cols].round(3).to_latex())

# %% [markdown]
# ## Gaussian mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="gaussian")
# Out:
# <style type="text/css">
# #T_94174_row0_col6, #T_94174_row0_col12, #T_94174_row1_col6, #T_94174_row2_col6, #T_94174_row5_col12, #T_94174_row6_col6, #T_94174_row7_col6, #T_94174_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_94174_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 54.8%, transparent 54.8%);
# }
# #T_94174_row0_col15, #T_94174_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_94174_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 85.0%, transparent 85.0%);
# }
# #T_94174_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_94174_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.9%, transparent 96.9%);
# }
# #T_94174_row2_col12, #T_94174_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_94174_row2_col15, #T_94174_row5_col15, #T_94174_row7_col15, #T_94174_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_94174_row3_col6, #T_94174_row4_col6, #T_94174_row5_col6, #T_94174_row8_col9, #T_94174_row11_col12, #T_94174_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_94174_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 21.4%, transparent 21.4%);
# }
# #T_94174_row3_col12, #T_94174_row8_col12, #T_94174_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_94174_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# #T_94174_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 48.3%, transparent 48.3%);
# }
# #T_94174_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_94174_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_94174_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 74.3%, transparent 74.3%);
# }
# #T_94174_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 71.0%, transparent 71.0%);
# }
# #T_94174_row6_col12, #T_94174_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_94174_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.6%, transparent 94.6%);
# }
# #T_94174_row9_col6, #T_94174_row10_col6, #T_94174_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_94174_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 28.6%, transparent 28.6%);
# }
# #T_94174_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_94174_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_94174_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 63.7%, transparent 63.7%);
# }
# #T_94174_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_94174_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.2%, transparent 88.2%);
# }
# </style>
# <table id="T_94174_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94174_row0_col0" class="data row0 col0" >20,000</td>
#       <td id="T_94174_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_94174_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_94174_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_94174_row0_col4" class="data row0 col4" >20,000</td>
#       <td id="T_94174_row0_col5" class="data row0 col5" >0.030</td>
#       <td id="T_94174_row0_col6" class="data row0 col6" >0.948</td>
#       <td id="T_94174_row0_col7" class="data row0 col7" >0.036</td>
#       <td id="T_94174_row0_col8" class="data row0 col8" >0.031</td>
#       <td id="T_94174_row0_col9" class="data row0 col9" >0.510</td>
#       <td id="T_94174_row0_col10" class="data row0 col10" >0.329</td>
#       <td id="T_94174_row0_col11" class="data row0 col11" >0.095</td>
#       <td id="T_94174_row0_col12" class="data row0 col12" >0.948</td>
#       <td id="T_94174_row0_col13" class="data row0 col13" >0.110</td>
#       <td id="T_94174_row0_col14" class="data row0 col14" >0.095</td>
#       <td id="T_94174_row0_col15" class="data row0 col15" >0.952</td>
#       <td id="T_94174_row0_col16" class="data row0 col16" >0.109</td>
#       <td id="T_94174_row0_col17" class="data row0 col17" >0.001</td>
#     </tr>
#     <tr>
#       <td id="T_94174_row1_col0" class="data row1 col0" >20,000</td>
#       <td id="T_94174_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_94174_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_94174_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_94174_row1_col4" class="data row1 col4" >20,000</td>
#       <td id="T_94174_row1_col5" class="data row1 col5" >0.030</td>
#       <td id="T_94174_row1_col6" class="data row1 col6" >0.948</td>
#       <td id="T_94174_row1_col7" class="data row1 col7" >0.036</td>
#       <td id="T_94174_row1_col8" class="data row1 col8" >0.030</td>
#       <td id="T_94174_row1_col9" class="data row1 col9" >0.791</td>
#       <td id="T_94174_row1_col10" class="data row1 col10" >0.074</td>
#       <td id="T_94174_row1_col11" class="data row1 col11" >0.047</td>
#       <td id="T_94174_row1_col12" class="data row1 col12" >0.952</td>
#       <td id="T_94174_row1_col13" class="data row1 col13" >0.054</td>
#       <td id="T_94174_row1_col14" class="data row1 col14" >0.047</td>
#       <td id="T_94174_row1_col15" class="data row1 col15" >0.953</td>
#       <td id="T_94174_row1_col16" class="data row1 col16" >0.054</td>
#       <td id="T_94174_row1_col17" class="data row1 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_94174_row2_col0" class="data row2 col0" >20,000</td>
#       <td id="T_94174_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_94174_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_94174_row2_col3" class="data row2 col3" >0.000001</td>
#       <td id="T_94174_row2_col4" class="data row2 col4" >20,000</td>
#       <td id="T_94174_row2_col5" class="data row2 col5" >0.030</td>
#       <td id="T_94174_row2_col6" class="data row2 col6" >0.948</td>
#       <td id="T_94174_row2_col7" class="
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &    20000.000 &  20000 &      0.2 &     0.030 &       0.948 &             0.036 &      0.031 &        0.510 &              0.329 &     0.095 &       0.948 &             0.110 &     0.095 &       0.952 &             0.109 \\
# 1  &    1 &    20000.000 &  20000 &      0.5 &     0.030 &       0.948 &             0.036 &      0.030 &        0.791 &              0.074 &     0.047 &       0.952 &             0.054 &     0.047 &       0.953 &             0.054 \\
# 2  &    1 &    20000.000 &  20000 &      1.0 &     0.030 &       0.948 &             0.036 &      0.030 &        0.902 &              0.042 &     0.035 &       0.950 &             0.040 &     0.035 &       0.951 &             0.040 \\
# 3  &    3 &    12322.645 &  20000 &      0.2 &     0.039 &       0.958 &             0.045 &      0.039 &        0.199 &              1.950 &     0.332 &       0.944 &             0.386 &     0.330 &       0.945 &             0.385 \\
# 4  &    3 &    12322.645 &  20000 &      0.5 &     0.039 &       0.958 &             0.045 &      0.039 &        0.450 &              0.514 &     0.136 &       0.942 &             0.159 &     0.136 &       0.943 &             0.158 \\
# 5  &    3 &    12322.645 &  20000 &      1.0 &     0.039 &       0.958 &             0.045 &      0.039 &        0.692 &              0.156 &     0.076 &       0.948 &             0.086 &     0.076 &       0.951 &             0.085 \\
# 6  &    1 &    50000.000 &  50000 &      0.2 &     0.019 &       0.948 &             0.024 &      0.019 &        0.661 &              0.098 &     0.041 &       0.947 &             0.048 &     0.041 &       0.950 &             0.048 \\
# 7  &    1 &    50000.000 &  50000 &      0.5 &     0.019 &       0.948 &             0.024 &      0.019 &        0.881 &              0.032 &     0.024 &       0.947 &             0.028 &     0.024 &       0.951 &             0.028 \\
# 8  &    1 &    50000.000 &  50000 &      1.0 &     0.019 &       0.948 &             0.024 &      0.019 &        0.931 &              0.025 &     0.021 &       0.944 &             0.025 &     0.021 &       0.944 &             0.025 \\
# 9  &    3 &    30799.788 &  50000 &      0.2 &     0.025 &       0.957 &             0.029 &      0.025 &        0.266 &              0.686 &     0.132 &       0.954 &             0.157 &     0.133 &       0.955 &             0.157 \\
# 10 &    3 &    30799.788 &  50000 &      0.5 &     0.025 &       0.957 &             0.029 &      0.025 &        0.593 &              0.155 &     0.057 &       0.949 &             0.068 &     0.058 &       0.951 &             0.068 \\
# 11 &    3 &    30799.788 &  50000 &      1.0 &     0.025 &       0.957 &             0.029 &      0.025 &        0.821 &              0.054 &     0.036 &       0.958 &             0.043 &     0.036 &       0.958 &             0.043 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200, mechanism="gaussian")
# Out:
# <style type="text/css">
# #T_2b772_row0_col6, #T_2b772_row1_col6, #T_2b772_row2_col6, #T_2b772_row2_col15, #T_2b772_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_2b772_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 54.4%, transparent 54.4%);
# }
# #T_2b772_row0_col12, #T_2b772_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_2b772_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.0%, transparent 92.0%);
# }
# #T_2b772_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 84.9%, transparent 84.9%);
# }
# #T_2b772_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_2b772_row1_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.2%, transparent 97.2%);
# }
# #T_2b772_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.6%, transparent 96.6%);
# }
# #T_2b772_row2_col12, #T_2b772_row6_col6, #T_2b772_row7_col6, #T_2b772_row8_col6, #T_2b772_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_2b772_row3_col6, #T_2b772_row4_col6, #T_2b772_row5_col6, #T_2b772_row8_col9, #T_2b772_row8_col15, #T_2b772_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_2b772_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 21.4%, transparent 21.4%);
# }
# #T_2b772_row3_col12, #T_2b772_row8_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_2b772_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.4%, transparent 90.4%);
# }
# #T_2b772_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 47.8%, transparent 47.8%);
# }
# #T_2b772_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_2b772_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 91.9%, transparent 91.9%);
# }
# #T_2b772_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 73.9%, transparent 73.9%);
# }
# #T_2b772_row5_col12, #T_2b772_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_2b772_row5_col15, #T_2b772_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.8%, transparent 94.8%);
# }
# #T_2b772_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 70.8%, transparent 70.8%);
# }
# #T_2b772_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.3%, transparent 94.3%);
# }
# #T_2b772_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.0%, transparent 98.0%);
# }
# #T_2b772_row9_col6, #T_2b772_row10_col6, #T_2b772_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_2b772_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 28.5%, transparent 28.5%);
# }
# #T_2b772_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.6%, transparent 92.6%);
# }
# #T_2b772_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 63.4%, transparent 63.4%);
# }
# #T_2b772_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.9%, transparent 94.9%);
# }
# #T_2b772_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.1%, transparent 88.1%);
# }
# #T_2b772_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# </style>
# <table id="T_2b772_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b772_row0_col0" class="data row0 col0" >20,000</td>
#       <td id="T_2b772_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_2b772_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_2b772_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_2b772_row0_col4" class="data row0 col4" >20,000</td>
#       <td id="T_2b772_row0_col5" class="data row0 col5" >0.027</td>
#       <td id="T_2b772_row0_col6" class="data row0 col6" >0.945</td>
#       <td id="T_2b772_row0_col7" class="data row0 col7" >0.033</td>
#       <td id="T_2b772_row0_col8" class="data row0 col8" >0.027</td>
#       <td id="T_2b772_row0_col9" class="data row0 col9" >0.506</td>
#       <td id="T_2b772_row0_col10" class="data row0 col10" >0.301</td>
#       <td id="T_2b772_row0_col11" class="data row0 col11" >0.086</td>
#       <td id="T_2b772_row0_col12" class="data row0 col12" >0.946</td>
#       <td id="T_2b772_row0_col13" class="data row0 col13" >0.100</td>
#       <td id="T_2b772_row0_col14" class="data row0 col14" >0.066</td>
#       <td id="T_2b772_row0_col15" class="data row0 col15" >0.863</td>
#       <td id="T_2b772_row0_col16" class="data row0 col16" >0.116</td>
#       <td id="T_2b772_row0_col17" class="data row0 col17" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_2b772_row1_col0" class="data row1 col0" >20,000</td>
#       <td id="T_2b772_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_2b772_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_2b772_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_2b772_row1_col4" class="data row1 col4" >20,000</td>
#       <td id="T_2b772_row1_col5" class="data row1 col5" >0.027</td>
#       <td id="T_2b772_row1_col6" class="data row1 col6" >0.945</td>
#       <td id="T_2b772_row1_col7" class="data row1 col7" >0.033</td>
#       <td id="T_2b772_row1_col8" class="data row1 col8" >0.027</td>
#       <td id="T_2b772_row1_col9" class="data row1 col9" >0.790</td>
#       <td id="T_2b772_row1_col10" class="data row1 col10" >0.068</td>
#       <td id="T_2b772_row1_col11" class="data row1 col11" >0.043</td>
#       <td id="T_2b772_row1_col12" class="data row1 col12" >0.951</td>
#       <td id="T_2b772_row1_col13" class="data row1 col13" >0.049</td>
#       <td id="T_2b772_row1_col14" class="data row1 col14" >0.037</td>
#       <td id="T_2b772_row1_col15" class="data row1 col15" >0.912</td>
#       <td id="T_2b772_row1_col16" class="data row1 col16" >0.051</td>
#       <td id="T_2b772_row1_col17" class="data row1 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_2b772_row2_col0" class="data row2 col0" >20,000</td>
#       <td id="T_2b772_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_2b772_row2_col2" class="data row2 col2" >1.0<
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &    20000.000 &  20000 &      0.2 &     0.027 &       0.945 &             0.033 &      0.027 &        0.506 &              0.301 &     0.086 &       0.946 &             0.100 &     0.066 &       0.863 &             0.116 \\
# 1  &    1 &    20000.000 &  20000 &      0.5 &     0.027 &       0.945 &             0.033 &      0.027 &        0.790 &              0.068 &     0.043 &       0.951 &             0.049 &     0.037 &       0.912 &             0.051 \\
# 2  &    1 &    20000.000 &  20000 &      1.0 &     0.027 &       0.945 &             0.033 &      0.027 &        0.898 &              0.039 &     0.032 &       0.949 &             0.037 &     0.030 &       0.929 &             0.037 \\
# 3  &    3 &    12322.645 &  20000 &      0.2 &     0.035 &       0.955 &             0.041 &      0.035 &        0.199 &              1.765 &     0.299 &       0.944 &             0.354 &     0.222 &       0.848 &             0.419 \\
# 4  &    3 &    12322.645 &  20000 &      0.5 &     0.035 &       0.955 &             0.041 &      0.035 &        0.445 &              0.469 &     0.123 &       0.943 &             0.145 &     0.094 &       0.862 &             0.166 \\
# 5  &    3 &    12322.645 &  20000 &      1.0 &     0.035 &       0.955 &             0.041 &      0.035 &        0.687 &              0.143 &     0.069 &       0.947 &             0.078 &     0.056 &       0.889 &             0.084 \\
# 6  &    1 &    50000.000 &  50000 &      0.2 &     0.017 &       0.946 &             0.021 &      0.017 &        0.658 &              0.090 &     0.037 &       0.946 &             0.044 &     0.030 &       0.889 &             0.048 \\
# 7  &    1 &    50000.000 &  50000 &      0.5 &     0.017 &       0.946 &             0.021 &      0.017 &        0.877 &              0.029 &     0.022 &       0.947 &             0.026 &     0.020 &       0.919 &             0.026 \\
# 8  &    1 &    50000.000 &  50000 &      1.0 &     0.017 &       0.946 &             0.021 &      0.017 &        0.930 &              0.023 &     0.019 &       0.944 &             0.023 &     0.018 &       0.938 &             0.023 \\
# 9  &    3 &    30799.788 &  50000 &      0.2 &     0.022 &       0.954 &             0.027 &      0.022 &        0.265 &              0.625 &     0.120 &       0.949 &             0.143 &     0.090 &       0.869 &             0.160 \\
# 10 &    3 &    30799.788 &  50000 &      0.5 &     0.022 &       0.954 &             0.027 &      0.022 &        0.590 &              0.142 &     0.052 &       0.948 &             0.062 &     0.041 &       0.890 &             0.067 \\
# 11 &    3 &    30799.788 &  50000 &      1.0 &     0.022 &       0.954 &             0.027 &      0.022 &        0.819 &              0.050 &     0.032 &       0.958 &             0.039 &     0.028 &       0.922 &             0.040 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Laplace mechanism

# %%
#@title ratio scale {form-width:"20%"}
sim(delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_19ea2_row0_col6, #T_19ea2_row1_col6, #T_19ea2_row2_col6, #T_19ea2_row6_col6, #T_19ea2_row7_col6, #T_19ea2_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_19ea2_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.2%, transparent 93.2%);
# }
# #T_19ea2_row0_col12, #T_19ea2_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_19ea2_row0_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.3%, transparent 96.3%);
# }
# #T_19ea2_row1_col9, #T_19ea2_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_19ea2_row1_col12, #T_19ea2_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_19ea2_row1_col15, #T_19ea2_row2_col9, #T_19ea2_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_19ea2_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
# }
# #T_19ea2_row2_col15, #T_19ea2_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
# }
# #T_19ea2_row3_col6, #T_19ea2_row4_col6, #T_19ea2_row5_col6, #T_19ea2_row7_col12, #T_19ea2_row7_col15, #T_19ea2_row8_col9, #T_19ea2_row8_col12, #T_19ea2_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_19ea2_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 67.0%, transparent 67.0%);
# }
# #T_19ea2_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_19ea2_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.4%, transparent 92.4%);
# }
# #T_19ea2_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.9%, transparent 90.9%);
# }
# #T_19ea2_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.8%, transparent 95.8%);
# }
# #T_19ea2_row5_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_19ea2_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.5%, transparent 97.5%);
# }
# #T_19ea2_row6_col12, #T_19ea2_row9_col6, #T_19ea2_row10_col6, #T_19ea2_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_19ea2_row7_col9, #T_19ea2_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_19ea2_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 80.9%, transparent 80.9%);
# }
# #T_19ea2_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_19ea2_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 94.1%, transparent 94.1%);
# }
# #T_19ea2_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.2%, transparent 95.2%);
# }
# #T_19ea2_row10_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.2%, transparent 99.2%);
# }
# #T_19ea2_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_19ea2_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# </style>
# <table id="T_19ea2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19ea2_row0_col0" class="data row0 col0" >20,000</td>
#       <td id="T_19ea2_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_19ea2_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_19ea2_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_19ea2_row0_col4" class="data row0 col4" >20,000</td>
#       <td id="T_19ea2_row0_col5" class="data row0 col5" >0.030</td>
#       <td id="T_19ea2_row0_col6" class="data row0 col6" >0.948</td>
#       <td id="T_19ea2_row0_col7" class="data row0 col7" >0.036</td>
#       <td id="T_19ea2_row0_col8" class="data row0 col8" >0.030</td>
#       <td id="T_19ea2_row0_col9" class="data row0 col9" >0.887</td>
#       <td id="T_19ea2_row0_col10" class="data row0 col10" >0.051</td>
#       <td id="T_19ea2_row0_col11" class="data row0 col11" >0.038</td>
#       <td id="T_19ea2_row0_col12" class="data row0 col12" >0.950</td>
#       <td id="T_19ea2_row0_col13" class="data row0 col13" >0.046</td>
#       <td id="T_19ea2_row0_col14" class="data row0 col14" >0.034</td>
#       <td id="T_19ea2_row0_col15" class="data row0 col15" >0.917</td>
#       <td id="T_19ea2_row0_col16" class="data row0 col16" >0.048</td>
#       <td id="T_19ea2_row0_col17" class="data row0 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_19ea2_row1_col0" class="data row1 col0" >20,000</td>
#       <td id="T_19ea2_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_19ea2_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_19ea2_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_19ea2_row1_col4" class="data row1 col4" >20,000</td>
#       <td id="T_19ea2_row1_col5" class="data row1 col5" >0.030</td>
#       <td id="T_19ea2_row1_col6" class="data row1 col6" >0.948</td>
#       <td id="T_19ea2_row1_col7" class="data row1 col7" >0.036</td>
#       <td id="T_19ea2_row1_col8" class="data row1 col8" >0.030</td>
#       <td id="T_19ea2_row1_col9" class="data row1 col9" >0.932</td>
#       <td id="T_19ea2_row1_col10" class="data row1 col10" >0.039</td>
#       <td id="T_19ea2_row1_col11" class="data row1 col11" >0.032</td>
#       <td id="T_19ea2_row1_col12" class="data row1 col12" >0.944</td>
#       <td id="T_19ea2_row1_col13" class="data row1 col13" >0.038</td>
#       <td id="T_19ea2_row1_col14" class="data row1 col14" >0.031</td>
#       <td id="T_19ea2_row1_col15" class="data row1 col15" >0.940</td>
#       <td id="T_19ea2_row1_col16" class="data row1 col16" >0.038</td>
#       <td id="T_19ea2_row1_col17" class="data row1 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_19ea2_row2_col0" class="data row2 col0" >20,000</td>
#       <td id="T_19ea2_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_19ea2_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_19ea2_row2_col3" class="data row2 col3" >0.000001</td>
#       <td id="T_19ea2_row2_col4" class="data row2 col4" >20,000</td>
#       <td id="T_19ea2_row2_col5" class="data row2 col5" >0.030</td>
#       <td id="T_19ea2_row2_col6" class="data row2 col6" >0.948</td>
#       <td id="T_19ea2_row2_col7" class=
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &    20000.000 &  20000 &      0.2 &     0.030 &       0.948 &             0.036 &      0.030 &        0.887 &              0.051 &     0.038 &       0.950 &             0.046 &     0.034 &       0.917 &             0.048 \\
# 1  &    1 &    20000.000 &  20000 &      0.5 &     0.030 &       0.948 &             0.036 &      0.030 &        0.932 &              0.039 &     0.032 &       0.944 &             0.038 &     0.031 &       0.940 &             0.038 \\
# 2  &    1 &    20000.000 &  20000 &      1.0 &     0.030 &       0.948 &             0.036 &      0.030 &        0.940 &              0.037 &     0.031 &       0.942 &             0.037 &     0.031 &       0.942 &             0.037 \\
# 3  &    3 &    12322.645 &  20000 &      0.2 &     0.039 &       0.958 &             0.045 &      0.039 &        0.638 &              0.238 &     0.090 &       0.939 &             0.118 &     0.070 &       0.880 &             0.132 \\
# 4  &    3 &    12322.645 &  20000 &      0.5 &     0.039 &       0.958 &             0.045 &      0.039 &        0.865 &              0.072 &     0.051 &       0.950 &             0.062 &     0.045 &       0.912 &             0.064 \\
# 5  &    3 &    12322.645 &  20000 &      1.0 &     0.039 &       0.958 &             0.045 &      0.039 &        0.932 &              0.051 &     0.042 &       0.949 &             0.051 &     0.041 &       0.942 &             0.051 \\
# 6  &    1 &    50000.000 &  50000 &      0.2 &     0.019 &       0.948 &             0.024 &      0.019 &        0.928 &              0.026 &     0.021 &       0.952 &             0.026 &     0.020 &       0.943 &             0.026 \\
# 7  &    1 &    50000.000 &  50000 &      0.5 &     0.019 &       0.948 &             0.024 &      0.019 &        0.946 &              0.024 &     0.020 &       0.953 &             0.024 &     0.019 &       0.952 &             0.024 \\
# 8  &    1 &    50000.000 &  50000 &      1.0 &     0.019 &       0.948 &             0.024 &      0.019 &        0.952 &              0.024 &     0.019 &       0.953 &             0.024 &     0.019 &       0.952 &             0.024 \\
# 9  &    3 &    30799.788 &  50000 &      0.2 &     0.025 &       0.957 &             0.029 &      0.025 &        0.770 &              0.074 &     0.041 &       0.946 &             0.050 &     0.034 &       0.896 &             0.053 \\
# 10 &    3 &    30799.788 &  50000 &      0.5 &     0.025 &       0.957 &             0.029 &      0.025 &        0.906 &              0.035 &     0.028 &       0.945 &             0.033 &     0.026 &       0.929 &             0.034 \\
# 11 &    3 &    30799.788 &  50000 &      1.0 &     0.025 &       0.957 &             0.029 &      0.025 &        0.935 &              0.031 &     0.025 &       0.947 &             0.031 &     0.025 &       0.940 &             0.031 \\
# \bottomrule
# \end{tabular}

# %%
#@title log_scale results {form-width: "20%"}
sim(log_scale=True, delta=1e-6, B=200, mechanism="laplace")
# Out:
# <style type="text/css">
# #T_7fdec_row0_col6, #T_7fdec_row1_col6, #T_7fdec_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
# }
# #T_7fdec_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 92.8%, transparent 92.8%);
# }
# #T_7fdec_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
# }
# #T_7fdec_row0_col15, #T_7fdec_row10_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 95.3%, transparent 95.3%);
# }
# #T_7fdec_row1_col9, #T_7fdec_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.9%, transparent 97.9%);
# }
# #T_7fdec_row1_col12, #T_7fdec_row9_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
# }
# #T_7fdec_row1_col15, #T_7fdec_row11_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.3%, transparent 98.3%);
# }
# #T_7fdec_row2_col9, #T_7fdec_row5_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
# }
# #T_7fdec_row2_col12, #T_7fdec_row6_col6, #T_7fdec_row7_col6, #T_7fdec_row8_col6, #T_7fdec_row10_col12, #T_7fdec_row11_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.1%, transparent 99.1%);
# }
# #T_7fdec_row2_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
# }
# #T_7fdec_row3_col6, #T_7fdec_row4_col6, #T_7fdec_row5_col6, #T_7fdec_row6_col12, #T_7fdec_row8_col9, #T_7fdec_row8_col12, #T_7fdec_row8_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_7fdec_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 66.7%, transparent 66.7%);
# }
# #T_7fdec_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
# }
# #T_7fdec_row3_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 85.7%, transparent 85.7%);
# }
# #T_7fdec_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 90.4%, transparent 90.4%);
# }
# #T_7fdec_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
# }
# #T_7fdec_row4_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 93.8%, transparent 93.8%);
# }
# #T_7fdec_row5_col12, #T_7fdec_row7_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
# }
# #T_7fdec_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 97.6%, transparent 97.6%);
# }
# #T_7fdec_row6_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.2%, transparent 98.2%);
# }
# #T_7fdec_row7_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
# }
# #T_7fdec_row7_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
# }
# #T_7fdec_row9_col6, #T_7fdec_row10_col6, #T_7fdec_row11_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
# }
# #T_7fdec_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 80.4%, transparent 80.4%);
# }
# #T_7fdec_row9_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 89.4%, transparent 89.4%);
# }
# #T_7fdec_row10_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 96.7%, transparent 96.7%);
# }
# #T_7fdec_row11_col15 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
# }
# </style>
# <table id="T_7fdec_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >u_w</th>
#       <th class="col_heading level0 col2" >epsilon</th>
#       <th class="col_heading level0 col3" >delta</th>
#       <th class="col_heading level0 col4" >effective_n</th>
#       <th class="col_heading level0 col5" >length_p</th>
#       <th class="col_heading level0 col6" >coverage_p</th>
#       <th class="col_heading level0 col7" >interval_score_p</th>
#       <th class="col_heading level0 col8" >length_nc</th>
#       <th class="col_heading level0 col9" >coverage_nc</th>
#       <th class="col_heading level0 col10" >interval_score_nc</th>
#       <th class="col_heading level0 col11" >length_m</th>
#       <th class="col_heading level0 col12" >coverage_m</th>
#       <th class="col_heading level0 col13" >interval_score_m</th>
#       <th class="col_heading level0 col14" >length_a</th>
#       <th class="col_heading level0 col15" >coverage_a</th>
#       <th class="col_heading level0 col16" >interval_score_a</th>
#       <th class="col_heading level0 col17" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7fdec_row0_col0" class="data row0 col0" >20,000</td>
#       <td id="T_7fdec_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7fdec_row0_col2" class="data row0 col2" >0.2</td>
#       <td id="T_7fdec_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_7fdec_row0_col4" class="data row0 col4" >20,000</td>
#       <td id="T_7fdec_row0_col5" class="data row0 col5" >0.027</td>
#       <td id="T_7fdec_row0_col6" class="data row0 col6" >0.945</td>
#       <td id="T_7fdec_row0_col7" class="data row0 col7" >0.033</td>
#       <td id="T_7fdec_row0_col8" class="data row0 col8" >0.027</td>
#       <td id="T_7fdec_row0_col9" class="data row0 col9" >0.882</td>
#       <td id="T_7fdec_row0_col10" class="data row0 col10" >0.047</td>
#       <td id="T_7fdec_row0_col11" class="data row0 col11" >0.034</td>
#       <td id="T_7fdec_row0_col12" class="data row0 col12" >0.946</td>
#       <td id="T_7fdec_row0_col13" class="data row0 col13" >0.042</td>
#       <td id="T_7fdec_row0_col14" class="data row0 col14" >0.029</td>
#       <td id="T_7fdec_row0_col15" class="data row0 col15" >0.905</td>
#       <td id="T_7fdec_row0_col16" class="data row0 col16" >0.045</td>
#       <td id="T_7fdec_row0_col17" class="data row0 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_7fdec_row1_col0" class="data row1 col0" >20,000</td>
#       <td id="T_7fdec_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7fdec_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_7fdec_row1_col3" class="data row1 col3" >0.000001</td>
#       <td id="T_7fdec_row1_col4" class="data row1 col4" >20,000</td>
#       <td id="T_7fdec_row1_col5" class="data row1 col5" >0.027</td>
#       <td id="T_7fdec_row1_col6" class="data row1 col6" >0.945</td>
#       <td id="T_7fdec_row1_col7" class="data row1 col7" >0.033</td>
#       <td id="T_7fdec_row1_col8" class="data row1 col8" >0.027</td>
#       <td id="T_7fdec_row1_col9" class="data row1 col9" >0.930</td>
#       <td id="T_7fdec_row1_col10" class="data row1 col10" >0.035</td>
#       <td id="T_7fdec_row1_col11" class="data row1 col11" >0.029</td>
#       <td id="T_7fdec_row1_col12" class="data row1 col12" >0.944</td>
#       <td id="T_7fdec_row1_col13" class="data row1 col13" >0.035</td>
#       <td id="T_7fdec_row1_col14" class="data row1 col14" >0.028</td>
#       <td id="T_7fdec_row1_col15" class="data row1 col15" >0.934</td>
#       <td id="T_7fdec_row1_col16" class="data row1 col16" >0.035</td>
#       <td id="T_7fdec_row1_col17" class="data row1 col17" >-0.000</td>
#     </tr>
#     <tr>
#       <td id="T_7fdec_row2_col0" class="data row2 col0" >20,000</td>
#       <td id="T_7fdec_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7fdec_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_7fdec_row2_col3" class="data row2 col3" >0.000001</td>
#       <td id="T_7fdec_row2_col4" class="data row2 col4" >20,000</td>
#       <td id="T_7fdec_row2_col5" class="data row2 col5" >0.027</td>
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &  u\_w &  effective\_n &      n &  epsilon &  length\_p &  coverage\_p &  interval\_score\_p &  length\_nc &  coverage\_nc &  interval\_score\_nc &  length\_m &  coverage\_m &  interval\_score\_m &  length\_a &  coverage\_a &  interval\_score\_a \\
# \midrule
# 0  &    1 &    20000.000 &  20000 &      0.2 &     0.027 &       0.945 &             0.033 &      0.027 &        0.882 &              0.047 &     0.034 &       0.946 &             0.042 &     0.029 &       0.905 &             0.045 \\
# 1  &    1 &    20000.000 &  20000 &      0.5 &     0.027 &       0.945 &             0.033 &      0.027 &        0.930 &              0.035 &     0.029 &       0.944 &             0.035 &     0.028 &       0.934 &             0.035 \\
# 2  &    1 &    20000.000 &  20000 &      1.0 &     0.027 &       0.945 &             0.033 &      0.027 &        0.935 &              0.033 &     0.028 &       0.942 &             0.033 &     0.028 &       0.936 &             0.033 \\
# 3  &    3 &    12322.645 &  20000 &      0.2 &     0.035 &       0.955 &             0.041 &      0.035 &        0.634 &              0.219 &     0.082 &       0.939 &             0.108 &     0.052 &       0.814 &             0.143 \\
# 4  &    3 &    12322.645 &  20000 &      0.5 &     0.035 &       0.955 &             0.041 &      0.035 &        0.859 &              0.066 &     0.046 &       0.948 &             0.057 &     0.038 &       0.891 &             0.061 \\
# 5  &    3 &    12322.645 &  20000 &      1.0 &     0.035 &       0.955 &             0.041 &      0.035 &        0.930 &              0.047 &     0.038 &       0.947 &             0.046 &     0.036 &       0.935 &             0.047 \\
# 6  &    1 &    50000.000 &  50000 &      0.2 &     0.017 &       0.946 &             0.021 &      0.017 &        0.927 &              0.024 &     0.019 &       0.951 &             0.023 &     0.018 &       0.933 &             0.024 \\
# 7  &    1 &    50000.000 &  50000 &      0.5 &     0.017 &       0.946 &             0.021 &      0.017 &        0.944 &              0.022 &     0.018 &       0.949 &             0.022 &     0.017 &       0.946 &             0.022 \\
# 8  &    1 &    50000.000 &  50000 &      1.0 &     0.017 &       0.946 &             0.021 &      0.017 &        0.950 &              0.021 &     0.017 &       0.951 &             0.021 &     0.017 &       0.950 &             0.021 \\
# 9  &    3 &    30799.788 &  50000 &      0.2 &     0.022 &       0.954 &             0.027 &      0.022 &        0.764 &              0.068 &     0.037 &       0.944 &             0.045 &     0.027 &       0.849 &             0.054 \\
# 10 &    3 &    30799.788 &  50000 &      0.5 &     0.022 &       0.954 &             0.027 &      0.022 &        0.905 &              0.032 &     0.025 &       0.942 &             0.030 &     0.023 &       0.919 &             0.031 \\
# 11 &    3 &    30799.788 &  50000 &      1.0 &     0.022 &       0.954 &             0.027 &      0.022 &        0.934 &              0.028 &     0.023 &       0.942 &             0.028 &     0.022 &       0.937 &             0.028 \\
# \bottomrule
# \end{tabular}

# %%
print(f"""
For the same epsilon=0.2 and sensitivity=1, the noise scale
for gaussian: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="gaussian"):.3f}
for laplace: {get_noise_scale(Delta=1, epsilon=0.2, delta=1e-6, mechanism="laplace"):.3f}
""")
# Out:
# For the same epsilon-0.2 and sensitivity=1, the noise scale
# for gaussian: 26.494
# for laplace: 5.000
